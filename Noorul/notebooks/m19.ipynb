# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import lightgbm as lgb
from IPython.display import clear_output
import time
import catboost
import re
import optuna
import json
import sys
sys.path.append('../..')
import main

from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, StackingClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (FunctionTransformer, StandardScaler, MinMaxScaler, RobustScaler, QuantileTransformer, PowerTransformer,
                                   OneHotEncoder)
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, KFold, StratifiedShuffleSplit
from sklearn.base import BaseEstimator, TransformerMixin

col_names = []
with open('../data/Faults27x7_var','r') as f:
    for line in f:
        col_names.append(line.strip())
        
train_org = pd.read_csv('../data/train.csv')
test_org = pd.read_csv('../data/test.csv')
org_data = pd.read_csv('../data/Faults.NNA', delimiter='\s', engine='python', names=col_names)

df = pd.concat([train_org.drop(['id'],axis=1),org_data]).reset_index(drop=True)
X = df.drop(['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps','Other_Faults'], axis=1)
pastry = df['Pastry'].copy()
z_scratch = df['Z_Scratch'].copy()
k_scatch = df['K_Scatch'].copy()
stains = df['Stains'].copy()
dirtiness = df['Dirtiness'].copy()
bumps = df['Bumps'].copy()
other_faults = df['Other_Faults'].copy()

ys = [pastry, z_scratch, k_scatch, stains, dirtiness, bumps, other_faults]
y_names = ['pastry', 'z_scratch', 'k_scatch', 'stains', 'dirtiness', 'bumps', 'other_faults']

class KMeansTransformer(BaseEstimator,TransformerMixin):
    def __init__(self, n_clusters):
        self.n_clusters = n_clusters
        self.kmeans = KMeans(n_clusters=self.n_clusters, n_init=10, random_state=0)
        
    def fit(self,X, y=None):
        self.kmeans.fit(X)
        return self
        
    def transform(self,X):
        labels = self.kmeans.predict(X)
        return np.c_[X, labels]

# %%
xtrain_pastry = pd.concat([X,pastry], axis=1)

# %%
pastry_predictor = TabularPredictor(label='Pastry', eval_metric='roc_auc')
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240320_045657"

# %%
pastry_predictor.fit(xtrain_pastry, time_limit=3600, presets='best_quality')
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 3600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240320_045657/ds_sub_fit/sub_fit_ho.
# Beginning AutoGluon training ... Time limit = 900s
# AutoGluon will save models to "AutogluonModels\ag-20240320_045657/ds_sub_fit/sub_fit_ho"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.9.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       8.15 GB / 15.63 GB (52.1%)
# Disk Space Avail:   158.66 GB / 241.59 GB (65.7%)
# ===================================================
# Train Data Rows:    18808
# Train Data Columns: 27
# Label Column:       Pastry
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8341.03 MB
# 	Train Data (Original)  Memory Usage: 3.87 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 14 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  2 | ['TypeOfSteel_A300', 'TypeOfSteel_A400']
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.62 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 599.77s of the 899.88s of remaining time.
# 	0.5372	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 597.87s of the 897.98s of remaining time.
# 	0.538	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 597.44s of the 897.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.8821	 = Validation score   (roc_auc)
# 	1.89s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 586.73s of the 886.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# 	0.8803	 = Validation score   (roc_auc)
# 	2.58s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 581.94s of the 882.04s of remaining time.
# 	0.8654	 = Validation score   (roc_auc)
# 	1.56s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 579.84s of the 879.94s of remaining time.
# 	0.871	 = Validation score   (roc_auc)
# 	1.64s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 577.67s of the 877.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	0.8851	 = Validation score   (roc_auc)
# 	13.39s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 562.26s of the 862.37s of remaining time.
# 	0.8708	 = Validation score   (roc_auc)
# 	0.81s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 560.86s of the 860.97s of remaining time.
# 	0.8711	 = Validation score   (roc_auc)
# 	0.78s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 559.47s of the 859.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.8744	 = Validation score   (roc_auc)
# 	23.84s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 533.48s of the 833.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.65%)
# 	0.8814	 = Validation score   (roc_auc)
# 	3.57s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 527.35s of the 827.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.874	 = Validation score   (roc_auc)
# 	22.75s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 502.25s of the 802.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.64%)
# 	0.8771	 = Validation score   (roc_auc)
# 	4.91s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 494.81s of the 794.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	0.8845	 = Validation score   (roc_auc)
# 	11.93s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 480.61s of the 780.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8701	 = Validation score   (roc_auc)
# 	49.28s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 429.05s of the 729.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.44%)
# 	0.8825	 = Validation score   (roc_auc)
# 	4.88s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 421.73s of the 721.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.8747	 = Validation score   (roc_auc)
# 	83.98s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 335.36s of the 635.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.90%)
# 	0.8821	 = Validation score   (roc_auc)
# 	39.12s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 293.93s of the 594.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8843	 = Validation score   (roc_auc)
# 	7.78s	 = Training   runtime
# 	1.9s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 283.17s of the 583.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.872	 = Validation score   (roc_auc)
# 	73.65s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 206.89s of the 507.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.45%)
# 	0.8802	 = Validation score   (roc_auc)
# 	9.63s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 194.86s of the 494.96s of remaining time.
# 	0.8695	 = Validation score   (roc_auc)
# 	1.29s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 193.01s of the 493.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	0.8844	 = Validation score   (roc_auc)
# 	10.35s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 180.25s of the 480.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8764	 = Validation score   (roc_auc)
# 	14.83s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 162.84s of the 462.95s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.07%)
# 	0.8841	 = Validation score   (roc_auc)
# 	65.37s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 94.47s of the 394.58s of remaining time.
# 	0.8577	 = Validation score   (roc_auc)
# 	5.77s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 88.17s of the 388.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.879	 = Validation score   (roc_auc)
# 	4.41s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 80.9s of the 381.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# 	0.876	 = Validation score   (roc_auc)
# 	61.73s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 16.34s of the 316.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.71%)
# 	0.882	 = Validation score   (roc_auc)
# 	3.84s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 9.53s of the 309.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	0.8618	 = Validation score   (roc_auc)
# 	11.08s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 295.58s of remaining time.
# 	Ensemble Weights: {'CatBoost_r177_BAG_L1': 0.21, 'CatBoost_r137_BAG_L1': 0.12, 'CatBoost_BAG_L1': 0.11, 'XGBoost_BAG_L1': 0.11, 'LightGBM_r131_BAG_L1': 0.09, 'NeuralNetFastAI_BAG_L1': 0.08, 'ExtraTrees_r42_BAG_L1': 0.08, 'NeuralNetFastAI_r102_BAG_L1': 0.07, 'NeuralNetTorch_r22_BAG_L1': 0.05, 'ExtraTreesGini_BAG_L1': 0.02, 'LightGBM_r96_BAG_L1': 0.02, 'NeuralNetFastAI_r145_BAG_L1': 0.02, 'NeuralNetTorch_r79_BAG_L1': 0.01, 'XGBoost_r33_BAG_L1': 0.01}
# 	0.8885	 = Validation score   (roc_auc)
# 	4.88s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 290.66s of the 290.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8844	 = Validation score   (roc_auc)
# 	3.68s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 284.54s of the 284.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.70%)
# 	0.8801	 = Validation score   (roc_auc)
# 	4.41s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 277.18s of the 277.1s of remaining time.
# 	0.8715	 = Validation score   (roc_auc)
# 	4.12s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 272.4s of the 272.32s of remaining time.
# 	0.878	 = Validation score   (roc_auc)
# 	4.01s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 267.7s of the 267.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.76%)
# 	0.8849	 = Validation score   (roc_auc)
# 	13.74s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 251.4s of the 251.31s of remaining time.
# 	0.8781	 = Validation score   (roc_auc)
# 	0.95s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 249.72s of the 249.64s of remaining time.
# 	0.8775	 = Validation score   (roc_auc)
# 	0.95s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 248.04s of the 247.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.83%)
# 	0.884	 = Validation score   (roc_auc)
# 	29.0s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 216.42s of the 216.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.11%)
# 	0.8809	 = Validation score   (roc_auc)
# 	6.3s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 207.1s of the 207.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.50%)
# 	0.8822	 = Validation score   (roc_auc)
# 	21.6s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 182.64s of the 182.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.05%)
# 	0.8784	 = Validation score   (roc_auc)
# 	8.71s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 171.26s of the 171.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.78%)
# 	0.8849	 = Validation score   (roc_auc)
# 	12.96s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 155.74s of the 155.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	0.8845	 = Validation score   (roc_auc)
# 	33.5s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 119.56s of the 119.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.75%)
# 	0.8808	 = Validation score   (roc_auc)
# 	7.52s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 109.26s of the 109.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.86%)
# 	0.8856	 = Validation score   (roc_auc)
# 	83.65s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 22.9s of the 22.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.63%)
# 	0.8856	 = Validation score   (roc_auc)
# 	19.93s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -0.41s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.213, 'CatBoost_r177_BAG_L1': 0.213, 'NeuralNetFastAI_BAG_L2': 0.149, 'NeuralNetFastAI_r102_BAG_L1': 0.128, 'XGBoost_BAG_L1': 0.085, 'XGBoost_r33_BAG_L1': 0.064, 'LightGBM_r131_BAG_L1': 0.043, 'NeuralNetFastAI_r145_BAG_L1': 0.043, 'NeuralNetFastAI_r191_BAG_L1': 0.021, 'RandomForestEntr_BAG_L2': 0.021, 'NeuralNetFastAI_r191_BAG_L2': 0.021}
# 	0.8882	 = Validation score   (roc_auc)
# 	4.57s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 905.02s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240320_045657/ds_sub_fit/sub_fit_ho")
# Leaderboard on holdout data from dynamic stacking:
#                           model  holdout_score  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         NeuralNetTorch_BAG_L2       0.866915   0.882209     roc_auc        6.625890      10.656922  558.274100                 0.400573                0.412924          21.602197            2       True         41
# 1     NeuralNetTorch_r79_BAG_L2       0.866482   0.884451     roc_auc        6.660481      10.716489  570.171013                 0.435164                0.472490          33.499110            2       True         44
# 2           LightGBM_r96_BAG_L1       0.866104   0.884279     roc_auc        0.438657       1.903074    7.783659                 0.438657                1.903074           7.783659            1       True         19
# 3             LightGBMXT_BAG_L2       0.865698   0.884367     roc_auc        6.322750      10.352939  540.351429                 0.097434                0.108941           3.679526            2       True         32
# 4            CatBoost_r9_BAG_L2       0.865576   0.885557     roc_auc        6.306942      10.277603  556.601587                 0.081626                0.033605          19.929684            2       True         47
# 5               CatBoost_BAG_L2       0.865429   0.884900     roc_auc        6.296928      10.260363  550.413254                 0.071611                0.016365          13.741351            2       True         36
# 6   NeuralNetFastAI_r191_BAG_L2       0.865029   0.885627     roc_auc        6.713516      10.795346  620.317591                 0.488199                0.551348          83.645688            2       True         46
# 7             LightGBMXT_BAG_L1       0.864869   0.882064     roc_auc        0.139943       0.279802    1.890858                 0.139943                0.279802           1.890858            1       True          3
# 8          CatBoost_r177_BAG_L2       0.864800   0.884910     roc_auc        6.349749      10.277749  549.629940                 0.124433                0.033751          12.958037            2       True         43
# 9     NeuralNetTorch_r79_BAG_L1       0.864601   0.870074     roc_auc        0.268764       0.293020   49.277810                 0.268764                0.293020          49.277810            1       True         15
# 10       NeuralNetFastAI_BAG_L2       0.864551   0.884027     roc_auc        6.579736      10.550407  565.667499                 0.354420                0.306409          28.995596            2       True         39
# 11          WeightedEnsemble_L2       0.864545   0.888472     roc_auc        3.620849       5.625227  291.834067                 0.013652                0.001826           4.883456            2       True         31
# 12          WeightedEnsemble_L3       0.864413   0.888170     roc_auc        7.186724      11.663735  657.897501                 0.007294                0.009616           4.570777            3       True         48
# 13          CatBoost_r13_BAG_L1       0.863500   0.884059     roc_auc        0.091105       0.023347   65.365472                 0.091105                0.023347          65.365472            1       True         25
# 14        ExtraTreesEntr_BAG_L2       0.863284   0.877475     roc_auc        6.349061      10.837205  537.618318                 0.123745                0.593207           0.946415            2       True         38
# 15         LightGBM_r131_BAG_L2       0.863146   0.880815     roc_auc        6.387822      10.599229  544.192823                 0.162505                0.355231           7.520920            2       True         45
# 16              LightGBM_BAG_L2       0.863103   0.880136     roc_auc        6.315757      10.321896  541.080684                 0.090440                0.077898           4.408781            2       True         33
# 17       NeuralNetFastAI_BAG_L1       0.862988   0.874390     roc_auc        0.464742       0.241463   23.835696                 0.464742                0.241463          23.835696            1       True         10
# 18    NeuralNetTorch_r22_BAG_L1       0.862624   0.871970     roc_auc        0.351869       0.470293   73.646683                 0.351869                0.470293          73.646683            1       True         20
# 19  NeuralNetFastAI_r191_BAG_L1       0.862614   0.874667     roc_auc        0.449331       0.490355   83.981461                 0.449331                0.490355          83.981461            1       True         17
# 20               XGBoost_BAG_L2       0.862510   0.880909     roc_auc        6.421684      10.365563  542.968457                 0.196368                0.121564           6.296554            2       True         40
# 21           CatBoost_r9_BAG_L1       0.862372   0.882070     roc_auc        0.083097       0.027906   39.124860                 0.083097                0.027906          39.124860            1       True         18
# 22         LightGBM_r188_BAG_L1       0.861975   0.878968     roc_auc        0.163522       0.304686    4.406732                 0.163522                0.304686           4.406732            1       True         27
# 23           XGBoost_r89_BAG_L1       0.861932   0.881974     roc_auc        0.184379       0.119570    3.844277                 0.184379                0.119570           3.844277            1       True         29
# 24  NeuralNetFastAI_r145_BAG_L1       0.861828   0.875979     roc_auc        0.534549       0.597817   61.725868                 0.534549                0.597817          61.725868            1       True         28
# 25              CatBoost_BAG_L1       0.861667   0.885061     roc_auc        0.072603       0.016231   13.392327                 0.072603                0.016231          13.392327            1       True          7
# 26         CatBoost_r177_BAG_L1       0.861230   0.884470     roc_auc        0.097105       0.021547   11.929848                 0.097105                0.021547          11.929848            1       True         14
# 27  NeuralNetFastAI_r102_BAG_L1       0.861064   0.876359     roc_auc        0.218101       0.166713   14.828347                 0.218101                0.166713          14.828347            1       True         24
# 28         LightGBMLarge_BAG_L2       0.860827   0.878408     roc_auc        6.329270      10.380575  545.379205                 0.103954                0.136577           8.707302            2       True         42
# 29         LightGBM_r131_BAG_L1       0.860733   0.882500     roc_auc        0.199238       0.507715    4.882605                 0.199238                0.507715           4.882605            1       True         16
# 30      RandomForestEntr_BAG_L2       0.860493   0.878047     roc_auc        6.336811      10.796363  540.685441                 0.111495                0.552364           4.013538            2       True         35
# 31              LightGBM_BAG_L1       0.860438   0.880313     roc_auc        0.096266       0.105904    2.584349                 0.096266                0.105904           2.584349            1       True          4
# 32    NeuralNetTorch_r30_BAG_L1       0.860275   0.861755     roc_auc        0.381069       0.582649   11.082153                 0.381069                0.582649          11.082153            1       True         30
# 33         CatBoost_r137_BAG_L1       0.860125   0.884385     roc_auc        0.072404       0.024136   10.351142                 0.072404                0.024136          10.351142            1       True         23
# 34      RandomForestEntr_BAG_L1       0.859943   0.870990     roc_auc        0.115001       0.399886    1.643664                 0.115001                0.399886           1.643664            1       True          6
# 35               XGBoost_BAG_L1       0.858965   0.881445     roc_auc        0.204563       0.071712    3.570522                 0.204563                0.071712           3.570522            1       True         11
# 36      RandomForestGini_BAG_L2       0.858915   0.871481     roc_auc        6.391743      10.778684  540.789077                 0.166427                0.534685           4.117173            2       True         34
# 37           XGBoost_r33_BAG_L1       0.858346   0.880222     roc_auc        0.358443       0.429444    9.629682                 0.358443                0.429444           9.629682            1       True         21
# 38        NeuralNetTorch_BAG_L1       0.858005   0.874046     roc_auc        0.247337       0.145205   22.747790                 0.247337                0.145205          22.747790            1       True         12
# 39        ExtraTreesGini_BAG_L1       0.857714   0.870831     roc_auc        0.163448       0.451711    0.809355                 0.163448                0.451711           0.809355            1       True          8
# 40         LightGBMLarge_BAG_L1       0.855862   0.877101     roc_auc        0.117930       0.136592    4.905256                 0.117930                0.136592           4.905256            1       True         13
# 41        ExtraTreesGini_BAG_L2       0.855425   0.878134     roc_auc        6.355726      10.834463  537.620808                 0.130410                0.590465           0.948905            2       True         37
# 42        ExtraTreesEntr_BAG_L1       0.852427   0.871098     roc_auc        0.148964       0.455364    0.780979                 0.148964                0.455364           0.780979            1       True          9
# 43      RandomForestGini_BAG_L1       0.851698   0.865409     roc_auc        0.145996       0.416998    1.560133                 0.145996                0.416998           1.560133            1       True          5
# 44        ExtraTrees_r42_BAG_L1       0.848617   0.869512     roc_auc        0.162711       0.428526    1.287066                 0.162711                0.428526           1.287066            1       True         22
# 45     RandomForest_r195_BAG_L1       0.842877   0.857724     roc_auc        0.111479       0.395757    5.770092                 0.111479                0.395757           5.770092            1       True         26
# 46        KNeighborsDist_BAG_L1       0.534922   0.538044     roc_auc        0.075781       0.371819    0.017548                 0.075781                0.371819           0.017548            1       True          2
# 47        KNeighborsUnif_BAG_L1       0.528383   0.537205     roc_auc        0.066921       0.364756    0.015669                 0.066921                0.364756           0.015669            1       True          1
# Stacked overfitting occurred: False.
# Spend 915 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 2685 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 2685s
# AutoGluon will save models to "AutogluonModels\ag-20240320_045657"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.9.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       7.62 GB / 15.63 GB (48.8%)
# Disk Space Avail:   158.66 GB / 241.59 GB (65.7%)
# ===================================================
# Train Data Rows:    21160
# Train Data Columns: 27
# Label Column:       Pastry
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7807.99 MB
# 	Train Data (Original)  Memory Usage: 4.36 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 14 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  2 | ['TypeOfSteel_A300', 'TypeOfSteel_A400']
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.08 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.13s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 1789.46s of the 2684.86s of remaining time.
# 	0.5404	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 1788.81s of the 2684.2s of remaining time.
# 	0.5418	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1788.09s of the 2683.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	0.8818	 = Validation score   (roc_auc)
# 	3.41s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1781.75s of the 2677.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# 	0.8793	 = Validation score   (roc_auc)
# 	3.13s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1776.33s of the 2671.72s of remaining time.
# 	0.8638	 = Validation score   (roc_auc)
# 	2.01s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1773.76s of the 2669.15s of remaining time.
# 	0.8674	 = Validation score   (roc_auc)
# 	1.96s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1771.25s of the 2666.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	0.8812	 = Validation score   (roc_auc)
# 	16.23s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1752.74s of the 2648.13s of remaining time.
# 	0.8697	 = Validation score   (roc_auc)
# 	0.87s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1751.22s of the 2646.62s of remaining time.
# 	0.8712	 = Validation score   (roc_auc)
# 	0.9s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1749.68s of the 2645.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	0.8734	 = Validation score   (roc_auc)
# 	27.12s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1720.34s of the 2615.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.74%)
# 	0.8788	 = Validation score   (roc_auc)
# 	3.76s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1713.92s of the 2609.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	0.8719	 = Validation score   (roc_auc)
# 	24.39s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1687.14s of the 2582.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.64%)
# 	0.8735	 = Validation score   (roc_auc)
# 	4.88s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 1679.77s of the 2575.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.53%)
# 	0.8812	 = Validation score   (roc_auc)
# 	11.78s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 1665.58s of the 2560.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.8708	 = Validation score   (roc_auc)
# 	45.76s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 1617.48s of the 2512.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	0.8797	 = Validation score   (roc_auc)
# 	5.22s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 1609.78s of the 2505.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# 	0.8737	 = Validation score   (roc_auc)
# 	90.36s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 1516.99s of the 2412.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.92%)
# 	0.88	 = Validation score   (roc_auc)
# 	40.11s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 1474.23s of the 2369.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# 	0.8835	 = Validation score   (roc_auc)
# 	7.8s	 = Training   runtime
# 	2.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 1463.85s of the 2359.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.8735	 = Validation score   (roc_auc)
# 	75.32s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 1386.15s of the 2281.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.52%)
# 	0.8777	 = Validation score   (roc_auc)
# 	10.14s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 1373.56s of the 2268.95s of remaining time.
# 	0.8648	 = Validation score   (roc_auc)
# 	1.25s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 1371.72s of the 2267.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.8813	 = Validation score   (roc_auc)
# 	9.24s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 1360.24s of the 2255.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8733	 = Validation score   (roc_auc)
# 	14.44s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 1343.41s of the 2238.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.15%)
# 	0.8808	 = Validation score   (roc_auc)
# 	59.35s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 1281.3s of the 2176.7s of remaining time.
# 	0.8559	 = Validation score   (roc_auc)
# 	6.47s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 1274.23s of the 2169.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8786	 = Validation score   (roc_auc)
# 	3.77s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 1268.01s of the 2163.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.8745	 = Validation score   (roc_auc)
# 	60.28s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 1205.2s of the 2100.6s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.66%)
# 	0.8792	 = Validation score   (roc_auc)
# 	2.49s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 1197.03s of the 2092.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	0.8704	 = Validation score   (roc_auc)
# 	70.7s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 1123.92s of the 2019.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8767	 = Validation score   (roc_auc)
# 	3.22s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 1118.32s of the 2013.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.8686	 = Validation score   (roc_auc)
# 	53.82s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 1062.12s of the 1957.51s of remaining time.
# ...
# 	0.8796	 = Validation score   (roc_auc)
# 	4.8s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 621.22s of the 1516.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.8455	 = Validation score   (roc_auc)
# 	223.49s	 = Training   runtime
# 	0.99s	 = Validation runtime
# Fitting model: CatBoost_r86_BAG_L1 ... Training model for up to 394.92s of the 1290.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.87%)
# 	0.8814	 = Validation score   (roc_auc)
# 	27.0s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37_BAG_L1 ... Training model for up to 365.78s of the 1261.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	0.8746	 = Validation score   (roc_auc)
# 	38.75s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197_BAG_L1 ... Training model for up to 324.79s of the 1220.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# 	0.8699	 = Validation score   (roc_auc)
# 	21.08s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: CatBoost_r49_BAG_L1 ... Training model for up to 301.04s of the 1196.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	0.8812	 = Validation score   (roc_auc)
# 	9.33s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTrees_r49_BAG_L1 ... Training model for up to 289.32s of the 1184.71s of remaining time.
# 	0.8697	 = Validation score   (roc_auc)
# 	1.01s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: LightGBM_r143_BAG_L1 ... Training model for up to 287.66s of the 1183.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.70%)
# 	0.8728	 = Validation score   (roc_auc)
# 	6.85s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: RandomForest_r127_BAG_L1 ... Training model for up to 278.33s of the 1173.72s of remaining time.
# 	0.8631	 = Validation score   (roc_auc)
# 	8.02s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134_BAG_L1 ... Training model for up to 269.78s of the 1165.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# 	0.8684	 = Validation score   (roc_auc)
# 	67.75s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: RandomForest_r34_BAG_L1 ... Training model for up to 199.72s of the 1095.12s of remaining time.
# 	0.8712	 = Validation score   (roc_auc)
# 	4.28s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: LightGBM_r94_BAG_L1 ... Training model for up to 194.99s of the 1090.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.8823	 = Validation score   (roc_auc)
# 	3.89s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143_BAG_L1 ... Training model for up to 188.66s of the 1084.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.8717	 = Validation score   (roc_auc)
# 	93.8s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: CatBoost_r128_BAG_L1 ... Training model for up to 92.51s of the 987.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.87%)
# 	0.8799	 = Validation score   (roc_auc)
# 	35.3s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111_BAG_L1 ... Training model for up to 54.97s of the 950.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	0.875	 = Validation score   (roc_auc)
# 	19.16s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31_BAG_L1 ... Training model for up to 33.47s of the 928.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# 	0.8735	 = Validation score   (roc_auc)
# 	30.31s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: ExtraTrees_r4_BAG_L1 ... Training model for up to 0.45s of the 895.84s of remaining time.
# 	0.8741	 = Validation score   (roc_auc)
# 	1.24s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 893.79s of remaining time.
# 	Ensemble Weights: {'LightGBM_r96_BAG_L1': 0.196, 'CatBoost_r50_BAG_L1': 0.174, 'CatBoost_r70_BAG_L1': 0.174, 'LightGBMXT_BAG_L1': 0.109, 'NeuralNetTorch_r22_BAG_L1': 0.065, 'NeuralNetFastAI_r95_BAG_L1': 0.065, 'NeuralNetTorch_r31_BAG_L1': 0.065, 'XGBoost_BAG_L1': 0.043, 'ExtraTrees_r172_BAG_L1': 0.043, 'CatBoost_r49_BAG_L1': 0.043, 'NeuralNetTorch_r14_BAG_L1': 0.022}
# 	0.8857	 = Validation score   (roc_auc)
# 	5.08s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 888.68s of the 888.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.99%)
# 	0.8802	 = Validation score   (roc_auc)
# 	4.22s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 882.08s of the 881.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.07%)
# 	0.8784	 = Validation score   (roc_auc)
# 	5.31s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 874.43s of the 874.26s of remaining time.
# 	0.8696	 = Validation score   (roc_auc)
# 	6.3s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 867.24s of the 867.08s of remaining time.
# 	0.872	 = Validation score   (roc_auc)
# 	6.36s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 860.01s of the 859.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.22%)
# 	0.8838	 = Validation score   (roc_auc)
# 	18.65s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 839.02s of the 838.86s of remaining time.
# 	0.875	 = Validation score   (roc_auc)
# 	1.14s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 836.95s of the 836.79s of remaining time.
# 	0.8776	 = Validation score   (roc_auc)
# 	1.09s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 834.95s of the 834.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.33%)
# 	0.8832	 = Validation score   (roc_auc)
# 	30.15s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 802.41s of the 802.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.64%)
# 	0.8791	 = Validation score   (roc_auc)
# 	7.67s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 792.08s of the 791.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.80%)
# 	0.8815	 = Validation score   (roc_auc)
# 	22.29s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 767.23s of the 767.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.75%)
# 	0.8751	 = Validation score   (roc_auc)
# 	12.13s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 752.56s of the 752.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.28%)
# 	0.8829	 = Validation score   (roc_auc)
# 	15.96s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 734.19s of the 734.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.75%)
# 	0.8803	 = Validation score   (roc_auc)
# 	51.86s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 679.74s of the 679.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.17%)
# 	0.8796	 = Validation score   (roc_auc)
# 	8.4s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 668.9s of the 668.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.48%)
# 	0.8827	 = Validation score   (roc_auc)
# 	89.74s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 576.55s of the 576.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.63%)
# 	0.8824	 = Validation score   (roc_auc)
# 	77.73s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 496.48s of the 496.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.90%)
# 	0.8821	 = Validation score   (roc_auc)
# 	4.58s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 489.41s of the 489.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.74%)
# 	0.8811	 = Validation score   (roc_auc)
# 	64.84s	 = Training   runtime
# 	1.2s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 422.07s of the 421.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=4.81%)
# 	0.877	 = Validation score   (roc_auc)
# 	25.29s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 394.32s of the 394.16s of remaining time.
# 	0.872	 = Validation score   (roc_auc)
# 	3.61s	 = Training   runtime
# 	0.74s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 389.82s of the 389.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.90%)
# 	0.8831	 = Validation score   (roc_auc)
# 	9.12s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 378.32s of the 378.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.40%)
# 	0.8819	 = Validation score   (roc_auc)
# 	16.07s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 359.73s of the 359.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.24%)
# 	0.8831	 = Validation score   (roc_auc)
# 	97.95s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L2 ... Training model for up to 259.11s of the 258.94s of remaining time.
# 	0.8643	 = Validation score   (roc_auc)
# 	54.72s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L2 ... Training model for up to 203.51s of the 203.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.63%)
# 	0.8783	 = Validation score   (roc_auc)
# 	5.26s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 195.63s of the 195.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.44%)
# 	0.8836	 = Validation score   (roc_auc)
# 	62.28s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L2 ... Training model for up to 130.73s of the 130.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.51%)
# 	0.8804	 = Validation score   (roc_auc)
# 	6.78s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L2 ... Training model for up to 121.37s of the 121.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.83%)
# 	0.8817	 = Validation score   (roc_auc)
# 	81.11s	 = Training   runtime
# 	0.99s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L2 ... Training model for up to 37.21s of the 37.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.42%)
# 	0.8748	 = Validation score   (roc_auc)
# 	6.38s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L2 ... Training model for up to 28.46s of the 28.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.78%)
# 	0.8804	 = Validation score   (roc_auc)
# 	26.42s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 359.99s of the -1.52s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_r145_BAG_L2': 0.235, 'CatBoost_r70_BAG_L1': 0.21, 'LightGBM_r96_BAG_L1': 0.111, 'NeuralNetTorch_r79_BAG_L2': 0.086, 'LightGBMXT_BAG_L1': 0.049, 'NeuralNetTorch_BAG_L2': 0.049, 'CatBoost_BAG_L2': 0.037, 'ExtraTreesEntr_BAG_L2': 0.037, 'NeuralNetFastAI_r191_BAG_L2': 0.037, 'NeuralNetTorch_r22_BAG_L2': 0.037, 'NeuralNetTorch_r86_BAG_L2': 0.037, 'XGBoost_BAG_L1': 0.025, 'NeuralNetFastAI_BAG_L2': 0.025, 'NeuralNetTorch_r30_BAG_L2': 0.025}
# 	0.8857	 = Validation score   (roc_auc)
# 	5.09s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2691.64s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240320_045657")

# %%
pastry_predictor.leaderboard()
# Out:
#                           model  score_val eval_metric  pred_time_val  \
# 0           WeightedEnsemble_L2   0.885739     roc_auc       4.549237
# 1           WeightedEnsemble_L3   0.885679     roc_auc      34.048682
# 2               CatBoost_BAG_L2   0.883778     roc_auc      27.395413
# 3   NeuralNetFastAI_r145_BAG_L2   0.883555     roc_auc      28.016944
# 4           LightGBM_r96_BAG_L1   0.883454     roc_auc       2.077634
# ..                          ...        ...         ...            ...
# 93      RandomForest_r39_BAG_L1   0.860639     roc_auc       0.424011
# 94     RandomForest_r195_BAG_L1   0.855924     roc_auc       0.474392
# 95   NeuralNetTorch_r158_BAG_L1   0.845540     roc_auc       0.985989
# 96        KNeighborsDist_BAG_L1   0.541775     roc_auc       0.638645
# 97        KNeighborsUnif_BAG_L1   0.540432     roc_auc       0.597171
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0    236.985509                0.001998           5.081892            2
# 1   2103.580163                0.001999           5.087007            3
# 2   1668.709525                0.017840          18.653343            2
# 3   1712.332058                0.639371          62.275876            2
# 4      7.795454                2.077634           7.795454            1
# ..          ...                     ...                ...          ...
# 93     6.527032                0.424011           6.527032            1
# 94     6.474017                0.474392           6.474017            1
# 95   223.494192                0.985989         223.494192            1
# 96     0.023096                0.638645           0.023096            1
# 97     0.018084                0.597171           0.018084            1
#
#     can_infer  fit_order
# 0        True         67
# 1        True         98
# 2        True         72
# 3        True         93
# 4        True         19
# ..        ...        ...
# 93       True         45
# 94       True         26
# 95       True         51
# 96       True          2
# 97       True          1
#
# [98 rows x 10 columns]

# %%
pastry_predictor.evaluate(xtrain_pastry)
# Out:
# {'roc_auc': 0.9460429942649771,
#  'accuracy': 0.9353024574669188,
#  'balanced_accuracy': 0.5898013721289583,
#  'mcc': 0.383008926114043,
#  'f1': 0.30117406840224603,
#  'precision': 0.8805970149253731,
#  'recall': 0.1816502463054187}

# %%
nm = TabularPredictor.load('AutogluonModels/ag-20240320_045657')

# %%
nm.leaderboard()
# Out:
#                           model  score_val eval_metric  pred_time_val  \
# 0           WeightedEnsemble_L2   0.885739     roc_auc       4.549237
# 1           WeightedEnsemble_L3   0.885679     roc_auc      34.048682
# 2               CatBoost_BAG_L2   0.883778     roc_auc      27.395413
# 3   NeuralNetFastAI_r145_BAG_L2   0.883555     roc_auc      28.016944
# 4           LightGBM_r96_BAG_L1   0.883454     roc_auc       2.077634
# ..                          ...        ...         ...            ...
# 93      RandomForest_r39_BAG_L1   0.860639     roc_auc       0.424011
# 94     RandomForest_r195_BAG_L1   0.855924     roc_auc       0.474392
# 95   NeuralNetTorch_r158_BAG_L1   0.845540     roc_auc       0.985989
# 96        KNeighborsDist_BAG_L1   0.541775     roc_auc       0.638645
# 97        KNeighborsUnif_BAG_L1   0.540432     roc_auc       0.597171
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0    236.985509                0.001998           5.081892            2
# 1   2103.580163                0.001999           5.087007            3
# 2   1668.709525                0.017840          18.653343            2
# 3   1712.332058                0.639371          62.275876            2
# 4      7.795454                2.077634           7.795454            1
# ..          ...                     ...                ...          ...
# 93     6.527032                0.424011           6.527032            1
# 94     6.474017                0.474392           6.474017            1
# 95   223.494192                0.985989         223.494192            1
# 96     0.023096                0.638645           0.023096            1
# 97     0.018084                0.597171           0.018084            1
#
#     can_infer  fit_order
# 0        True         67
# 1        True         98
# 2        True         72
# 3        True         93
# 4        True         19
# ..        ...        ...
# 93       True         45
# 94       True         26
# 95       True         51
# 96       True          2
# 97       True          1
#
# [98 rows x 10 columns]

# %%
xtrain_z_scratch = pd.concat([X,z_scratch], axis=1)

# %%
z_scratch_predictor = TabularPredictor(label='Z_Scratch', eval_metric='roc_auc', path='AutogluonModels/z_scratch')

# %%
z_scratch_predictor.fit(xtrain_z_scratch, time_limit=3600, presets='best_quality')
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 3600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240320_005921/ds_sub_fit/sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 913 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 2687 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 2687s
# AutoGluon will save models to "AutogluonModels\ag-20240320_005921"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.9.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       7.78 GB / 15.63 GB (49.8%)
# Disk Space Avail:   160.17 GB / 241.59 GB (66.3%)
# ===================================================
# Train Data Rows:    20102
# Train Data Columns: 27
# Label Column:       Z_Scratch
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7994.58 MB
# 	Train Data (Original)  Memory Usage: 4.14 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 14 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  2 | ['TypeOfSteel_A300', 'TypeOfSteel_A400']
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.87 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.09s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 1790.82s of the 2686.9s of remaining time.
# 	0.5594	 = Validation score   (roc_auc)
# 	0.03s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 1790.27s of the 2686.35s of remaining time.
# 	0.5634	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1789.73s of the 2685.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.9625	 = Validation score   (roc_auc)
# 	1.98s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1783.92s of the 2680.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.41%)
# 	0.9621	 = Validation score   (roc_auc)
# 	3.04s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1778.44s of the 2674.51s of remaining time.
# 	0.9526	 = Validation score   (roc_auc)
# 	1.75s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1776.19s of the 2672.26s of remaining time.
# 	0.9552	 = Validation score   (roc_auc)
# 	1.71s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1774.02s of the 2670.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.44%)
# 	0.9647	 = Validation score   (roc_auc)
# 	11.78s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1760.01s of the 2656.09s of remaining time.
# 	0.9415	 = Validation score   (roc_auc)
# 	0.79s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 1758.58s of the 2654.66s of remaining time.
# 	0.9465	 = Validation score   (roc_auc)
# 	0.78s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1757.26s of the 2653.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.9521	 = Validation score   (roc_auc)
# 	26.5s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1728.49s of the 2624.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.69%)
# 	0.9621	 = Validation score   (roc_auc)
# 	3.62s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1722.03s of the 2618.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	0.9468	 = Validation score   (roc_auc)
# 	26.81s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1692.63s of the 2588.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.9618	 = Validation score   (roc_auc)
# 	5.15s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 1685.03s of the 2581.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# 	0.9646	 = Validation score   (roc_auc)
# 	11.45s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 1670.81s of the 2566.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	0.9507	 = Validation score   (roc_auc)
# 	62.15s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 1606.04s of the 2502.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.965	 = Validation score   (roc_auc)
# 	4.99s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 1598.63s of the 2494.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.9517	 = Validation score   (roc_auc)
# 	87.6s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 1508.65s of the 2404.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.86%)
# 	0.9643	 = Validation score   (roc_auc)
# 	39.46s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 1466.78s of the 2362.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.9628	 = Validation score   (roc_auc)
# 	7.93s	 = Training   runtime
# 	2.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 1456.13s of the 2352.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.9529	 = Validation score   (roc_auc)
# 	89.94s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 1363.81s of the 2259.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.44%)
# 	0.9636	 = Validation score   (roc_auc)
# 	10.12s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 1351.29s of the 2247.37s of remaining time.
# 	0.9508	 = Validation score   (roc_auc)
# 	1.07s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 1349.7s of the 2245.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.9651	 = Validation score   (roc_auc)
# 	9.64s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 1337.78s of the 2233.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.9527	 = Validation score   (roc_auc)
# 	13.44s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 1322.01s of the 2218.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.06%)
# 	0.9648	 = Validation score   (roc_auc)
# 	52.39s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 1266.86s of the 2162.93s of remaining time.
# 	0.9482	 = Validation score   (roc_auc)
# 	5.3s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 1261.07s of the 2157.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.9573	 = Validation score   (roc_auc)
# 	4.34s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 1254.33s of the 2150.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.9535	 = Validation score   (roc_auc)
# 	60.0s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 1191.85s of the 2087.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.70%)
# 	0.9654	 = Validation score   (roc_auc)
# 	3.4s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 1185.75s of the 2081.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.9531	 = Validation score   (roc_auc)
# 	141.62s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 1041.48s of the 1937.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# 	0.9638	 = Validation score   (roc_auc)
# 	3.11s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 1036.14s of the 1932.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	0.9478	 = Validation score   (roc_auc)
# 	72.07s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 961.61s of the 1857.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.9651	 = Validation score   (roc_auc)
# 	7.52s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 951.83s of the 1847.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.9509	 = Validation score   (roc_auc)
# 	97.5s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 852.0s of the 1748.07s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.69%)
# 	0.9633	 = Validation score   (roc_auc)
# 	4.33s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 845.01s of the 1741.09s of remaining time.
# 	0.9561	 = Validation score   (roc_auc)
# 	1.24s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 843.24s of the 1739.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# 	0.9645	 = Validation score   (roc_auc)
# 	9.48s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 831.55s of the 1727.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.9552	 = Validation score   (roc_auc)
# 	49.44s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 779.73s of the 1675.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.9418	 = Validation score   (roc_auc)
# 	14.35s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 762.6s of the 1658.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.86%)
# 	0.9598	 = Validation score   (roc_auc)
# 	7.58s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 751.94s of the 1648.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.9518	 = Validation score   (roc_auc)
# 	19.1s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 730.42s of the 1626.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# 	0.9645	 = Validation score   (roc_auc)
# 	17.71s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 710.15s of the 1606.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.9404	 = Validation score   (roc_auc)
# 	20.23s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 687.61s of the 1583.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.64%)
# 	0.9568	 = Validation score   (roc_auc)
# 	14.7s	 = Training   runtime
# 	6.95s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 668.63s of the 1564.7s of remaining time.
# 	0.9505	 = Validation score   (roc_auc)
# 	5.33s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 662.83s of the 1558.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.9652	 = Validation score   (roc_auc)
# 	14.02s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 646.53s of the 1542.6s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.9538	 = Validation score   (roc_auc)
# 	61.04s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41_BAG_L1 ... Training model for up to 582.83s of the 1478.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.9533	 = Validation score   (roc_auc)
# 	36.23s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: XGBoost_r98_BAG_L1 ... Training model for up to 543.9s of the 1439.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.94%)
# 	0.9648	 = Validation score   (roc_auc)
# 	16.27s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: LightGBM_r15_BAG_L1 ... Training model for up to 525.01s of the 1421.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.9652	 = Validation score   (roc_auc)
# 	3.75s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 518.9s of the 1414.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.9342	 = Validation score   (roc_auc)
# 	154.64s	 = Training   runtime
# 	1.03s	 = Validation runtime
# Fitting model: CatBoost_r86_BAG_L1 ... Training model for up to 361.54s of the 1257.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.84%)
# 	0.9639	 = Validation score   (roc_auc)
# 	28.89s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37_BAG_L1 ... Training model for up to 330.38s of the 1226.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.9573	 = Validation score   (roc_auc)
# 	38.19s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197_BAG_L1 ... Training model for up to 289.86s of the 1185.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.9482	 = Validation score   (roc_auc)
# 	28.17s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: CatBoost_r49_BAG_L1 ... Training model for up to 258.98s of the 1155.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.965	 = Validation score   (roc_auc)
# 	8.35s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTrees_r49_BAG_L1 ... Training model for up to 248.25s of the 1144.33s of remaining time.
# 	0.9415	 = Validation score   (roc_auc)
# 	0.96s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: LightGBM_r143_BAG_L1 ... Training model for up to 246.75s of the 1142.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.9577	 = Validation score   (roc_auc)
# 	6.94s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: RandomForest_r127_BAG_L1 ... Training model for up to 237.26s of the 1133.33s of remaining time.
# 	0.9514	 = Validation score   (roc_auc)
# 	6.83s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134_BAG_L1 ... Training model for up to 229.97s of the 1126.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.9451	 = Validation score   (roc_auc)
# 	66.78s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: RandomForest_r34_BAG_L1 ... Training model for up to 160.88s of the 1056.95s of remaining time.
# 	0.957	 = Validation score   (roc_auc)
# 	4.11s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: LightGBM_r94_BAG_L1 ... Training model for up to 156.32s of the 1052.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.9622	 = Validation score   (roc_auc)
# 	4.14s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143_BAG_L1 ... Training model for up to 149.61s of the 1045.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	0.9462	 = Validation score   (roc_auc)
# 	123.06s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: CatBoost_r128_BAG_L1 ... Training model for up to 23.73s of the 919.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.88%)
# 	0.9631	 = Validation score   (roc_auc)
# 	20.49s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111_BAG_L1 ... Training model for up to 0.76s of the 896.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8113	 = Validation score   (roc_auc)
# 	5.33s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 888.38s of remaining time.
# 	Ensemble Weights: {'CatBoost_r49_BAG_L1': 0.188, 'LightGBM_r130_BAG_L1': 0.174, 'CatBoost_r50_BAG_L1': 0.159, 'CatBoost_r167_BAG_L1': 0.116, 'LightGBM_r15_BAG_L1': 0.116, 'LightGBM_r131_BAG_L1': 0.058, 'XGBoost_r89_BAG_L1': 0.058, 'NeuralNetFastAI_r103_BAG_L1': 0.043, 'XGBoost_r194_BAG_L1': 0.029, 'XGBoost_r33_BAG_L1': 0.014, 'ExtraTrees_r172_BAG_L1': 0.014, 'NeuralNetTorch_r41_BAG_L1': 0.014, 'NeuralNetFastAI_r37_BAG_L1': 0.014}
# 	0.9672	 = Validation score   (roc_auc)
# 	4.95s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 883.41s of the 883.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.90%)
# 	0.9653	 = Validation score   (roc_auc)
# 	4.58s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 876.49s of the 876.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.92%)
# 	0.9647	 = Validation score   (roc_auc)
# 	5.41s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 868.69s of the 868.52s of remaining time.
# 	0.9589	 = Validation score   (roc_auc)
# 	5.06s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 862.83s of the 862.67s of remaining time.
# 	0.9588	 = Validation score   (roc_auc)
# 	4.3s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 857.79s of the 857.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.12%)
# 	0.9656	 = Validation score   (roc_auc)
# 	17.68s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 837.79s of the 837.63s of remaining time.
# 	0.9604	 = Validation score   (roc_auc)
# 	0.94s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 835.99s of the 835.83s of remaining time.
# 	0.9599	 = Validation score   (roc_auc)
# 	0.92s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 834.28s of the 834.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.21%)
# 	0.9614	 = Validation score   (roc_auc)
# 	28.37s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 803.5s of the 803.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.45%)
# 	0.9638	 = Validation score   (roc_auc)
# 	7.66s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 793.28s of the 793.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.9609	 = Validation score   (roc_auc)
# 	31.37s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 759.45s of the 759.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.58%)
# 	0.9609	 = Validation score   (roc_auc)
# 	12.54s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 744.46s of the 744.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.22%)
# 	0.9657	 = Validation score   (roc_auc)
# 	17.81s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 724.17s of the 724.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.66%)
# 	0.9625	 = Validation score   (roc_auc)
# 	30.2s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 691.44s of the 691.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.11%)
# 	0.9639	 = Validation score   (roc_auc)
# 	9.0s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 679.9s of the 679.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.26%)
# 	0.9619	 = Validation score   (roc_auc)
# 	84.09s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 593.29s of the 593.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.63%)
# 	0.9661	 = Validation score   (roc_auc)
# 	93.73s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 496.99s of the 496.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.82%)
# 	0.9653	 = Validation score   (roc_auc)
# 	4.89s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 489.66s of the 489.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.66%)
# 	0.9624	 = Validation score   (roc_auc)
# 	66.79s	 = Training   runtime
# 	0.91s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 420.43s of the 420.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=4.35%)
# 	0.9633	 = Validation score   (roc_auc)
# 	23.77s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 394.28s of the 394.12s of remaining time.
# 	0.9598	 = Validation score   (roc_auc)
# 	2.66s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 390.88s of the 390.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.81%)
# 	0.9656	 = Validation score   (roc_auc)
# 	13.32s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 375.24s of the 375.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.21%)
# 	0.9624	 = Validation score   (roc_auc)
# 	14.77s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 358.02s of the 357.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.16%)
# 	0.9657	 = Validation score   (roc_auc)
# 	144.71s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L2 ... Training model for up to 210.44s of the 210.29s of remaining time.
# 	0.9557	 = Validation score   (roc_auc)
# 	40.25s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L2 ... Training model for up to 169.43s of the 169.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.53%)
# 	0.9634	 = Validation score   (roc_auc)
# 	5.49s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 161.5s of the 161.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.33%)
# 	0.9633	 = Validation score   (roc_auc)
# 	60.44s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L2 ... Training model for up to 98.53s of the 98.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.52%)
# 	0.9647	 = Validation score   (roc_auc)
# 	6.68s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L2 ... Training model for up to 89.3s of the 89.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.70%)
# 	0.962	 = Validation score   (roc_auc)
# 	69.09s	 = Training   runtime
# 	0.9s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L2 ... Training model for up to 17.71s of the 17.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.33%)
# 	0.9607	 = Validation score   (roc_auc)
# 	6.47s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 7.81s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 0.206, 'LightGBM_r15_BAG_L1': 0.147, 'CatBoost_r13_BAG_L2': 0.147, 'XGBoost_r89_BAG_L1': 0.118, 'CatBoost_r9_BAG_L2': 0.118, 'NeuralNetTorch_r79_BAG_L2': 0.088, 'XGBoost_r98_BAG_L1': 0.059, 'LightGBMXT_BAG_L2': 0.059, 'LightGBM_r131_BAG_L1': 0.029, 'XGBoost_r89_BAG_L2': 0.029}
# 	0.967	 = Validation score   (roc_auc)
# 	4.85s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2684.16s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240320_005921")

# %%
z_scratch_predictor.evaluate(xtrain_z_scratch)
# Out:
# {'roc_auc': 0.9908073726089066,
#  'accuracy': 0.9719430902397771,
#  'balanced_accuracy': 0.844761534089603,
#  'mcc': 0.7477408196272993,
#  'f1': 0.7593856655290102,
#  'precision': 0.830999066293184,
#  'recall': 0.6991358994501178}

# %%
z_scratch_predictor.evaluate(xtest_z_scratch)
# Out:
# {'roc_auc': 0.9642754943747458,
#  'accuracy': 0.9508506616257089,
#  'balanced_accuracy': 0.716312483997771,
#  'mcc': 0.5221254098744341,
#  'f1': 0.5357142857142857,
#  'precision': 0.6666666666666666,
#  'recall': 0.44776119402985076}

# %%
xtr_k_scatch, xte_k_scatch, ytr_k_scatch, yte_k_scatch = train_test_split(X,k_scatch,test_size=0.05, stratify=k_scatch, random_state=0)

# %%
xtrain_k_scatch = pd.concat([xtr_k_scatch,ytr_k_scatch], axis=1)
xtest_k_scatch = pd.concat([xte_k_scatch,yte_k_scatch], axis=1)

# %%
k_scatch_predictor = TabularPredictor(label='K_Scatch', eval_metric='roc_auc')
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240320_015927"

# %%
k_scatch_predictor.fit(xtrain_k_scatch, time_limit=3600, presets='best_quality')
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 3600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240320_015927/ds_sub_fit/sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 k_scatch_predictor.fit(xtrain_k_scatch, time_limit=3600, presets='best_quality')
#
# File d:\App_Files\miniconda\envs\tf\lib\site-packages\autogluon\core\utils\decorators.py:31, in unpack.<locals>._unpack_inner.<locals>._call(*args, **kwargs)
#      28 @functools.wraps(f)
#      29 def _call(*args, **kwargs):
#      30     gargs, gkwargs = g(*other_args, *args, **kwargs)
# ---> 31     return f(*gargs, **gkwargs)
#
# File d:\App_Files\miniconda\envs\tf\lib\site-packages\autogluon\tabular\predictor\predictor.py:1099, in TabularPredictor.fit(self, train_data, tuning_data, time_limit, presets, hyperparameters, feature_metadata, infer_limit, infer_limit_batch_size, fit_weighted_ensemble, fit_full_last_level_weighted_ensemble, full_weighted_ensemble_additionally, dynamic_stacking, calibrate_decision_threshold, num_cpus, num_gpus, **kwargs)
#    1093 if dynamic_stacking:
#    1094     logger.log(
#    1095         20,
#    1096         f"Dynamic stacking is enabled (dynamic_stacking={dynamic_stacking}). "
#    1097         "AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.",
#    1098     )
# -> 1099     num_stack_levels, time_limit = self._dynamic_stacking(**ds_args, ag_fit_kwargs=ag_fit_kwargs, ag_post_fit_kwargs=ag_post_fit_kwargs)
#    1101     if (time_limit is not None) and (time_limit <= 0):
#    1102         raise ValueError(
#    1103             f"Not enough time left to train models for the full fit. Consider specifying a larger time_limit. Time remaining: {time_limit}s"
#    1104         )
#
# File d:\App_Files\miniconda\envs\tf\lib\site-packages\autogluon\tabular\predictor\predictor.py:1186, in TabularPredictor._dynamic_stacking(self, ag_fit_kwargs, ag_post_fit_kwargs, validation_procedure, detection_time_frac, holdout_frac, n_folds, n_repeats, memory_safe_fits, clean_up_fits, holdout_data)
#    1181         ds_fit_kwargs["ds_fit_context"] = ds_fit_context + "/sub_fit_custom_ho"
#    1182         logger.info(
#    1183             f"Starting holdout-based sub-fit for dynamic stacking with custom validation data. Context path is: {ds_fit_kwargs['ds_fit_context']}."
#    1184         )
# -> 1186     stacked_overfitting = self._sub_fit_memory_save_wrapper(
#    1187         train_data=X,
#    1188         time_limit=time_limit,
#    1189         ds_fit_kwargs=ds_fit_kwargs,
#    1190         ag_fit_kwargs=inner_ag_fit_kwargs,
#    1191         ag_post_fit_kwargs=inner_ag_post_fit_kwargs,
#    1192         holdout_data=holdout_data,
#    1193     )
#    1194 else:
#    1195     # Holdout is false, use (repeated) cross-validation
#    1196     is_stratified = self.problem_type in [REGRESSION, QUANTILE, SOFTCLASS]
#
# File d:\App_Files\miniconda\envs\tf\lib\site-packages\autogluon\tabular\predictor\predictor.py:1328, in TabularPredictor._sub_fit_memory_save_wrapper(self, train_data, time_limit, ds_fit_kwargs, ag_fit_kwargs, ag_post_fit_kwargs, holdout_data)
#    1318     sub_fit_caller = _ds_ray.remote(max_calls=1)(_sub_fit)
#    1319     ref = sub_fit_caller.options(num_cpus=num_cpus, num_gpus=num_gpus).remote(
#    1320         predictor=predictor_ref,
#    1321         train_data=train_data_ref,
#    (...)
#    1326         holdout_data=holdout_data_ref,
#    1327     )
# -> 1328     finished, unfinished = _ds_ray.wait([ref], num_returns=1)
#    1329     stacked_overfitting = _ds_ray.get(finished[0])
#    1330 else:
#
# File d:\App_Files\miniconda\envs\tf\lib\site-packages\ray\_private\auto_init_hook.py:24, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      21 @wraps(fn)
#      22 def auto_init_wrapper(*args, **kwargs):
#      23     auto_init_ray()
# ---> 24     return fn(*args, **kwargs)
#
# File d:\App_Files\miniconda\envs\tf\lib\site-packages\ray\_private\client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File d:\App_Files\miniconda\envs\tf\lib\site-packages\ray\_private\worker.py:2732, in wait(object_refs, num_returns, timeout, fetch_local)
#    2730 timeout = timeout if timeout is not None else 10**6
#    2731 timeout_milliseconds = int(timeout * 1000)
# -> 2732 ready_ids, remaining_ids = worker.core_worker.wait(
#    2733     object_refs,
#    2734     num_returns,
#    2735     timeout_milliseconds,
#    2736     worker.current_task_id,
#    2737     fetch_local,
#    2738 )
#    2739 return ready_ids, remaining_ids
#
# File python\ray\_raylet.pyx:3012, in ray._raylet.CoreWorker.wait()
#
# File python\ray\_raylet.pyx:400, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
k_scatch_predictor.evaluate(xtrain_k_scatch)
# Out:
# {'roc_auc': 0.9310208306075798,
#  'accuracy': 0.9292972575905974,
#  'balanced_accuracy': 0.5416709480942064,
#  'mcc': 0.2601406848662326,
#  'f1': 0.15384615384615385,
#  'precision': 0.8823529411764706,
#  'recall': 0.08426966292134831}

# %%
k_scatch_predictor.evaluate(xtest_k_scatch)
# Out:
# {'roc_auc': 0.8849383811832179,
#  'accuracy': 0.9240374609781478,
#  'balanced_accuracy': 0.5147825419042091,
#  'mcc': 0.1171556973782576,
#  'f1': 0.060085836909871244,
#  'precision': 0.5384615384615384,
#  'recall': 0.031818181818181815}

# %%
xtr_stains, xte_stains, ytr_stains, yte_stains = train_test_split(X,stains,test_size=0.05, stratify=stains, random_state=0)

# %%
xtrain_stains = pd.concat([xtr_stains,ytr_stains], axis=1)
xtest_stains = pd.concat([xte_stains,yte_stains], axis=1)

# %%
stains_predictor = TabularPredictor(label='Stains', eval_metric='roc_auc')
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240319_235032"

# %%
stains_predictor.fit(xtrain_stains, time_limit=3600, presets='best_quality')
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 1800 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240319_170823/ds_sub_fit/sub_fit_ho.
# Beginning AutoGluon training ... Time limit = 450s
# AutoGluon will save models to "AutogluonModels\ag-20240319_170823/ds_sub_fit/sub_fit_ho"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.9.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       6.82 GB / 15.63 GB (43.7%)
# Disk Space Avail:   162.85 GB / 241.59 GB (67.4%)
# ===================================================
# Train Data Rows:    14520
# Train Data Columns: 27
# Label Column:       Pastry
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6988.81 MB
# 	Train Data (Original)  Memory Usage: 2.99 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 14 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  2 | ['TypeOfSteel_A300', 'TypeOfSteel_A400']
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.80 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 299.86s of the 449.89s of remaining time.
# 	0.5321	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 298.0s of the 448.03s of remaining time.
# 	0.5313	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 297.63s of the 447.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8644	 = Validation score   (roc_auc)
# 	1.72s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 286.17s of the 436.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	0.8588	 = Validation score   (roc_auc)
# 	3.03s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 280.12s of the 430.15s of remaining time.
# 	0.8449	 = Validation score   (roc_auc)
# 	1.53s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 278.15s of the 428.18s of remaining time.
# 	0.8534	 = Validation score   (roc_auc)
# 	1.48s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 276.26s of the 426.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.47%)
# 	0.8678	 = Validation score   (roc_auc)
# 	12.8s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 260.96s of the 410.99s of remaining time.
# 	0.8549	 = Validation score   (roc_auc)
# 	0.85s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 259.63s of the 409.66s of remaining time.
# 	0.8547	 = Validation score   (roc_auc)
# 	0.88s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 258.26s of the 408.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.8575	 = Validation score   (roc_auc)
# 	22.48s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 233.31s of the 383.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.73%)
# 	0.859	 = Validation score   (roc_auc)
# 	3.75s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 226.72s of the 376.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.8612	 = Validation score   (roc_auc)
# 	21.39s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 202.75s of the 352.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.62%)
# 	0.8521	 = Validation score   (roc_auc)
# 	5.2s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 195.03s of the 345.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.8643	 = Validation score   (roc_auc)
# 	9.8s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 182.53s of the 332.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.8595	 = Validation score   (roc_auc)
# 	30.64s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 149.39s of the 299.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.8591	 = Validation score   (roc_auc)
# 	4.73s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 142.13s of the 292.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# 	0.8606	 = Validation score   (roc_auc)
# 	63.44s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 76.18s of the 226.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.95%)
# 	0.8626	 = Validation score   (roc_auc)
# 	42.32s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 31.44s of the 181.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	0.8675	 = Validation score   (roc_auc)
# 	5.62s	 = Training   runtime
# 	0.97s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 22.95s of the 172.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.27%)
# 	0.8616	 = Validation score   (roc_auc)
# 	23.19s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 146.93s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.303, 'NeuralNetTorch_r79_BAG_L1': 0.182, 'LightGBM_r96_BAG_L1': 0.152, 'ExtraTreesGini_BAG_L1': 0.091, 'NeuralNetTorch_r22_BAG_L1': 0.091, 'ExtraTreesEntr_BAG_L1': 0.061, 'NeuralNetFastAI_BAG_L1': 0.061, 'NeuralNetFastAI_r191_BAG_L1': 0.061}
# 	0.872	 = Validation score   (roc_auc)
# 	3.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 143.78s of the 143.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8672	 = Validation score   (roc_auc)
# 	3.79s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 137.42s of the 137.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.64%)
# 	0.8635	 = Validation score   (roc_auc)
# 	4.1s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 130.5s of the 130.43s of remaining time.
# 	0.8527	 = Validation score   (roc_auc)
# 	2.57s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 127.48s of the 127.42s of remaining time.
# 	0.8579	 = Validation score   (roc_auc)
# 	2.64s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 124.41s of the 124.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8689	 = Validation score   (roc_auc)
# 	16.97s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 104.91s of the 104.85s of remaining time.
# 	0.8576	 = Validation score   (roc_auc)
# 	0.97s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 103.46s of the 103.4s of remaining time.
# 	0.8592	 = Validation score   (roc_auc)
# 	0.9s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 102.04s of the 101.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8639	 = Validation score   (roc_auc)
# 	23.26s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 76.19s of the 76.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.02%)
# 	0.863	 = Validation score   (roc_auc)
# 	5.42s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 67.9s of the 67.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.44%)
# 	0.8619	 = Validation score   (roc_auc)
# 	18.43s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 46.71s of the 46.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.96%)
# 	0.8609	 = Validation score   (roc_auc)
# 	8.17s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 35.82s of the 35.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.73%)
# 	0.8682	 = Validation score   (roc_auc)
# 	14.3s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 18.8s of the 18.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.8646	 = Validation score   (roc_auc)
# 	18.91s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -3.64s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.235, 'NeuralNetTorch_r79_BAG_L1': 0.133, 'LightGBMLarge_BAG_L2': 0.133, 'LightGBM_r96_BAG_L1': 0.122, 'ExtraTreesGini_BAG_L1': 0.082, 'NeuralNetTorch_r22_BAG_L1': 0.071, 'NeuralNetFastAI_BAG_L1': 0.061, 'NeuralNetFastAI_r191_BAG_L1': 0.061, 'ExtraTreesEntr_BAG_L1': 0.051, 'NeuralNetTorch_r79_BAG_L2': 0.041, 'CatBoost_BAG_L2': 0.01}
# 	0.8722	 = Validation score   (roc_auc)
# 	4.11s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 457.79s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240319_170823/ds_sub_fit/sub_fit_ho")
# Leaderboard on holdout data from dynamic stacking:
#                           model  holdout_score  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         NeuralNetTorch_BAG_L2       0.873614   0.861888     roc_auc        4.527886       5.485740  273.313112                 0.349788                0.278650          18.434801            2       True         31
# 1           LightGBM_r96_BAG_L1       0.869362   0.867532     roc_auc        0.298535       0.965180    5.617690                 0.298535                0.965180           5.617690            1       True         19
# 2           WeightedEnsemble_L3       0.868384   0.872239     roc_auc        4.733640       5.794621  303.039897                 0.007313                0.000000           4.111024            3       True         35
# 3     NeuralNetTorch_r79_BAG_L2       0.868088   0.864588     roc_auc        4.545925       5.645229  273.787014                 0.367827                0.438139          18.908703            2       True         34
# 4           WeightedEnsemble_L2       0.867960   0.872024     roc_auc        2.433630       3.105907  163.008360                 0.009110                0.000000           3.120656            2       True         21
# 5        NeuralNetFastAI_BAG_L2       0.867436   0.863873     roc_auc        4.494735       5.460572  278.139149                 0.316637                0.253482          23.260838            2       True         29
# 6               CatBoost_BAG_L2       0.867175   0.868897     roc_auc        4.247594       5.230140  271.847259                 0.069496                0.023051          16.968948            2       True         26
# 7     NeuralNetTorch_r22_BAG_L1       0.867097   0.861601     roc_auc        0.394268       0.465677   23.190371                 0.394268                0.465677          23.190371            1       True         20
# 8          CatBoost_r177_BAG_L2       0.867089   0.868211     roc_auc        4.261637       5.221876  269.175098                 0.083539                0.014786          14.296788            2       True         33
# 9             LightGBMXT_BAG_L1       0.866973   0.864412     roc_auc        0.194320       0.171243    1.723201                 0.194320                0.171243           1.723201            1       True          3
# 10        NeuralNetTorch_BAG_L1       0.866921   0.861233     roc_auc        0.268147       0.174139   21.388237                 0.268147                0.174139          21.388237            1       True         12
# 11           CatBoost_r9_BAG_L1       0.866900   0.862627     roc_auc        0.089947       0.046070   42.323025                 0.089947                0.046070          42.323025            1       True         18
# 12              LightGBM_BAG_L2       0.866716   0.863546     roc_auc        4.268629       5.264540  258.981468                 0.090531                0.057450           4.103157            2       True         23
# 13               XGBoost_BAG_L2       0.866711   0.863040     roc_auc        4.397655       5.268077  260.295569                 0.219557                0.060987           5.417259            2       True         30
# 14         LightGBM_r131_BAG_L1       0.866149   0.859082     roc_auc        0.180791       0.283554    4.733950                 0.180791                0.283554           4.733950            1       True         16
# 15         LightGBMLarge_BAG_L2       0.866046   0.860891     roc_auc        4.289003       5.333431  263.051222                 0.110906                0.126341           8.172912            2       True         32
# 16              CatBoost_BAG_L1       0.866008   0.867808     roc_auc        0.081939       0.060104   12.796780                 0.081939                0.060104          12.796780            1       True          7
# 17            LightGBMXT_BAG_L2       0.865296   0.867189     roc_auc        4.288718       5.297197  258.669255                 0.110620                0.090107           3.790944            2       True         22
# 18              LightGBM_BAG_L1       0.865210   0.858768     roc_auc        0.110234       0.074260    3.028121                 0.110234                0.074260           3.028121            1       True          4
# 19         CatBoost_r177_BAG_L1       0.865206   0.864306     roc_auc        0.090326       0.009697    9.799675                 0.090326                0.009697           9.799675            1       True         14
# 20  NeuralNetFastAI_r191_BAG_L1       0.862902   0.860649     roc_auc        0.444258       0.392169   63.436638                 0.444258                0.392169          63.436638            1       True         17
# 21       NeuralNetFastAI_BAG_L1       0.862434   0.857494     roc_auc        0.596998       0.253464   22.481312                 0.596998                0.253464          22.481312            1       True         10
# 22        ExtraTreesGini_BAG_L2       0.862042   0.857587     roc_auc        4.309818       5.554199  255.845938                 0.131720                0.347109           0.967628            2       True         27
# 23               XGBoost_BAG_L1       0.861645   0.858972     roc_auc        0.242846       0.065260    3.749452                 0.242846                0.065260           3.749452            1       True         11
# 24        ExtraTreesEntr_BAG_L2       0.860933   0.859151     roc_auc        4.305810       5.583267  255.780347                 0.127712                0.376177           0.902036            2       True         28
# 25        ExtraTreesEntr_BAG_L1       0.860362   0.854702     roc_auc        0.159896       0.351333    0.876355                 0.159896                0.351333           0.876355            1       True          9
# 26    NeuralNetTorch_r79_BAG_L1       0.860324   0.859504     roc_auc        0.298723       0.272187   30.641757                 0.298723                0.272187          30.641757            1       True         15
# 27         LightGBMLarge_BAG_L1       0.860139   0.852080     roc_auc        0.120433       0.101993    5.200888                 0.120433                0.101993           5.200888            1       True         13
# 28      RandomForestGini_BAG_L2       0.856581   0.852720     roc_auc        4.319288       5.519481  257.443944                 0.141191                0.312391           2.565633            2       True         24
# 29      RandomForestEntr_BAG_L2       0.856042   0.857864     roc_auc        4.280041       5.513978  257.516303                 0.101943                0.306888           2.637992            2       True         25
# 30      RandomForestEntr_BAG_L1       0.855066   0.853374     roc_auc        0.150108       0.284240    1.483447                 0.150108                0.284240           1.483447            1       True          6
# 31        ExtraTreesGini_BAG_L1       0.853758   0.854901     roc_auc        0.149904       0.345792    0.846801                 0.149904                0.345792           0.846801            1       True          8
# 32      RandomForestGini_BAG_L1       0.845201   0.844905     roc_auc        0.188399       0.306392    1.527866                 0.188399                0.306392           1.527866            1       True          5
# 33        KNeighborsUnif_BAG_L1       0.563090   0.532084     roc_auc        0.062644       0.283167    0.010274                 0.062644                0.283167           0.010274            1       True          1
# 34        KNeighborsDist_BAG_L1       0.561130   0.531307     roc_auc        0.055382       0.301167    0.022471                 0.055382                0.301167           0.022471            1       True          2
# Stacked overfitting occurred: False.
# Spend 465 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 1335 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 1335s
# AutoGluon will save models to "AutogluonModels\ag-20240319_170823"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.9.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       6.61 GB / 15.63 GB (42.3%)
# Disk Space Avail:   162.85 GB / 241.59 GB (67.4%)
# ===================================================
# Train Data Rows:    16336
# Train Data Columns: 27
# Label Column:       Pastry
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6762.49 MB
# 	Train Data (Original)  Memory Usage: 3.37 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 14 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  2 | ['TypeOfSteel_A300', 'TypeOfSteel_A400']
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.15 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 889.69s of the 1334.86s of remaining time.
# 	0.5393	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 889.27s of the 1334.44s of remaining time.
# 	0.5396	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 888.85s of the 1334.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# 	0.8647	 = Validation score   (roc_auc)
# 	1.68s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 880.72s of the 1325.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	0.8628	 = Validation score   (roc_auc)
# 	3.49s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 874.37s of the 1319.54s of remaining time.
# 	0.8438	 = Validation score   (roc_auc)
# 	1.67s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 872.25s of the 1317.42s of remaining time.
# 	0.853	 = Validation score   (roc_auc)
# 	1.69s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 870.14s of the 1315.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.47%)
# 	0.8661	 = Validation score   (roc_auc)
# 	13.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 854.62s of the 1299.79s of remaining time.
# 	0.8532	 = Validation score   (roc_auc)
# 	0.91s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 853.13s of the 1298.3s of remaining time.
# 	0.8532	 = Validation score   (roc_auc)
# 	0.9s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 851.74s of the 1296.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8608	 = Validation score   (roc_auc)
# 	23.36s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 825.89s of the 1271.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8601	 = Validation score   (roc_auc)
# 	4.31s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 818.95s of the 1264.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8594	 = Validation score   (roc_auc)
# 	22.22s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 794.14s of the 1239.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.64%)
# 	0.8572	 = Validation score   (roc_auc)
# 	5.1s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 786.53s of the 1231.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8658	 = Validation score   (roc_auc)
# 	10.4s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 773.55s of the 1218.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8605	 = Validation score   (roc_auc)
# 	34.74s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 736.36s of the 1181.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	0.8624	 = Validation score   (roc_auc)
# 	4.62s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 729.17s of the 1174.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.62%)
# 	0.8611	 = Validation score   (roc_auc)
# 	73.31s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 653.14s of the 1098.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.94%)
# 	0.8644	 = Validation score   (roc_auc)
# 	43.27s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 607.36s of the 1052.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.8674	 = Validation score   (roc_auc)
# 	6.03s	 = Training   runtime
# 	1.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 598.55s of the 1043.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8605	 = Validation score   (roc_auc)
# 	53.97s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 541.79s of the 986.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.66%)
# 	0.8589	 = Validation score   (roc_auc)
# 	10.1s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 529.16s of the 974.33s of remaining time.
# 	0.8497	 = Validation score   (roc_auc)
# 	1.16s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 527.51s of the 972.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8664	 = Validation score   (roc_auc)
# 	9.8s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 515.25s of the 960.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8616	 = Validation score   (roc_auc)
# 	12.37s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 500.36s of the 945.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.28%)
# 	0.8675	 = Validation score   (roc_auc)
# 	43.72s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 453.58s of the 898.75s of remaining time.
# 	0.8367	 = Validation score   (roc_auc)
# 	5.8s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 447.34s of the 892.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8623	 = Validation score   (roc_auc)
# 	4.2s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 440.44s of the 885.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8627	 = Validation score   (roc_auc)
# 	52.78s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 384.87s of the 830.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8642	 = Validation score   (roc_auc)
# 	4.08s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 377.92s of the 823.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.8602	 = Validation score   (roc_auc)
# 	67.98s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 307.02s of the 752.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.861	 = Validation score   (roc_auc)
# 	3.59s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 300.67s of the 745.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.8549	 = Validation score   (roc_auc)
# 	31.76s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 266.01s of the 711.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.8676	 = Validation score   (roc_auc)
# 	8.01s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 255.29s of the 700.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8579	 = Validation score   (roc_auc)
# 	86.62s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 165.89s of the 611.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.73%)
# 	0.8575	 = Validation score   (roc_auc)
# 	3.75s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 159.8s of the 604.97s of remaining time.
# 	0.8586	 = Validation score   (roc_auc)
# 	1.19s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 158.21s of the 603.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# 	0.8668	 = Validation score   (roc_auc)
# 	8.24s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 147.68s of the 592.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8609	 = Validation score   (roc_auc)
# 	36.91s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 108.34s of the 553.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8618	 = Validation score   (roc_auc)
# 	11.81s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 94.1s of the 539.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.91%)
# 	0.8564	 = Validation score   (roc_auc)
# 	6.92s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 84.49s of the 529.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# 	0.8611	 = Validation score   (roc_auc)
# 	15.96s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 66.0s of the 511.17s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.8647	 = Validation score   (roc_auc)
# 	17.8s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 45.54s of the 490.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8574	 = Validation score   (roc_auc)
# 	16.65s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 26.51s of the 471.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.72%)
# 	0.8646	 = Validation score   (roc_auc)
# 	9.02s	 = Training   runtime
# 	2.81s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 13.69s of the 458.86s of remaining time.
# 	0.8426	 = Validation score   (roc_auc)
# 	5.31s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 7.96s of the 453.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# 	0.8661	 = Validation score   (roc_auc)
# 	8.01s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 442.41s of remaining time.
# 	Ensemble Weights: {'CatBoost_r50_BAG_L1': 0.18, 'LightGBM_r96_BAG_L1': 0.112, 'ExtraTrees_r172_BAG_L1': 0.101, 'CatBoost_r69_BAG_L1': 0.101, 'NeuralNetFastAI_r145_BAG_L1': 0.09, 'NeuralNetTorch_r79_BAG_L1': 0.079, 'NeuralNetTorch_r14_BAG_L1': 0.079, 'NeuralNetFastAI_r191_BAG_L1': 0.067, 'CatBoost_r167_BAG_L1': 0.056, 'LightGBM_BAG_L1': 0.045, 'NeuralNetTorch_r22_BAG_L1': 0.022, 'NeuralNetFastAI_r102_BAG_L1': 0.022, 'NeuralNetTorch_r30_BAG_L1': 0.022, 'NeuralNetFastAI_r103_BAG_L1': 0.022}
# 	0.8718	 = Validation score   (roc_auc)
# 	4.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 438.37s of the 438.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.77%)
# 	0.8649	 = Validation score   (roc_auc)
# 	3.75s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 432.27s of the 432.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.91%)
# 	0.8643	 = Validation score   (roc_auc)
# 	4.74s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 424.87s of the 424.75s of remaining time.
# 	0.8541	 = Validation score   (roc_auc)
# 	4.03s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 420.26s of the 420.14s of remaining time.
# 	0.8615	 = Validation score   (roc_auc)
# 	4.08s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 415.6s of the 415.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.97%)
# 	0.8688	 = Validation score   (roc_auc)
# 	17.67s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 395.56s of the 395.44s of remaining time.
# 	0.8596	 = Validation score   (roc_auc)
# 	0.9s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 394.02s of the 393.9s of remaining time.
# 	0.8616	 = Validation score   (roc_auc)
# 	0.92s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 392.5s of the 392.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.97%)
# 	0.8656	 = Validation score   (roc_auc)
# 	22.91s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 367.19s of the 367.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.28%)
# 	0.8626	 = Validation score   (roc_auc)
# 	6.65s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 358.04s of the 357.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8658	 = Validation score   (roc_auc)
# 	16.67s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 338.56s of the 338.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.43%)
# 	0.8614	 = Validation score   (roc_auc)
# 	10.24s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 325.82s of the 325.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.99%)
# 	0.8681	 = Validation score   (roc_auc)
# 	18.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 305.19s of the 305.07s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.53%)
# 	0.8655	 = Validation score   (roc_auc)
# 	39.51s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 263.04s of the 262.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.91%)
# 	0.8658	 = Validation score   (roc_auc)
# 	7.0s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 253.62s of the 253.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.00%)
# 	0.8672	 = Validation score   (roc_auc)
# 	61.45s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 189.76s of the 189.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.15%)
# 	0.8674	 = Validation score   (roc_auc)
# 	78.23s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 109.11s of the 108.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.66%)
# 	0.868	 = Validation score   (roc_auc)
# 	4.57s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 102.08s of the 101.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.8651	 = Validation score   (roc_auc)
# 	50.94s	 = Training   runtime
# 	0.7s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 48.67s of the 48.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.95%)
# 	0.8622	 = Validation score   (roc_auc)
# 	18.72s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 27.4s of the 27.28s of remaining time.
# 	0.8575	 = Validation score   (roc_auc)
# 	2.24s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 24.57s of the 24.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.8686	 = Validation score   (roc_auc)
# 	10.6s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 11.56s of the 11.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.98%)
# 	0.867	 = Validation score   (roc_auc)
# 	13.56s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -5.85s of remaining time.
# 	Ensemble Weights: {'CatBoost_r50_BAG_L1': 0.246, 'NeuralNetTorch_r79_BAG_L2': 0.123, 'LightGBM_r96_BAG_L1': 0.105, 'NeuralNetFastAI_r145_BAG_L1': 0.105, 'NeuralNetTorch_r14_BAG_L1': 0.088, 'NeuralNetTorch_r79_BAG_L1': 0.07, 'RandomForestEntr_BAG_L2': 0.07, 'NeuralNetTorch_r22_BAG_L2': 0.07, 'NeuralNetFastAI_r102_BAG_L1': 0.053, 'CatBoost_r177_BAG_L2': 0.053, 'CatBoost_BAG_L2': 0.018}
# 	0.8718	 = Validation score   (roc_auc)
# 	4.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1344.94s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240319_170823")

# %%
stains_predictor.evaluate(xtrain_stains)
# Out:
# {'roc_auc': 0.9310208306075798,
#  'accuracy': 0.9292972575905974,
#  'balanced_accuracy': 0.5416709480942064,
#  'mcc': 0.2601406848662326,
#  'f1': 0.15384615384615385,
#  'precision': 0.8823529411764706,
#  'recall': 0.08426966292134831}

# %%
stains_predictor.evaluate(xtest_stains)
# Out:
# {'roc_auc': 0.8849383811832179,
#  'accuracy': 0.9240374609781478,
#  'balanced_accuracy': 0.5147825419042091,
#  'mcc': 0.1171556973782576,
#  'f1': 0.060085836909871244,
#  'precision': 0.5384615384615384,
#  'recall': 0.031818181818181815}

# %%
xtr_dirtiness, xte_dirtiness, ytr_dirtiness, yte_dirtiness = train_test_split(X,dirtiness,test_size=0.05, stratify=dirtiness, random_state=0)

# %%
xtrain_dirtiness = pd.concat([xtr_dirtiness,ytr_dirtiness], axis=1)
xtest_dirtiness = pd.concat([xte_dirtiness,yte_dirtiness], axis=1)

# %%
dirtiness_predictor = TabularPredictor(label='Dirtiness', eval_metric='roc_auc')
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240319_235032"

# %%
dirtiness_predictor.fit(xtrain_dirtiness, time_limit=3600, presets='best_quality')
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 1800 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240319_170823/ds_sub_fit/sub_fit_ho.
# Beginning AutoGluon training ... Time limit = 450s
# AutoGluon will save models to "AutogluonModels\ag-20240319_170823/ds_sub_fit/sub_fit_ho"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.9.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       6.82 GB / 15.63 GB (43.7%)
# Disk Space Avail:   162.85 GB / 241.59 GB (67.4%)
# ===================================================
# Train Data Rows:    14520
# Train Data Columns: 27
# Label Column:       Pastry
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6988.81 MB
# 	Train Data (Original)  Memory Usage: 2.99 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 14 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  2 | ['TypeOfSteel_A300', 'TypeOfSteel_A400']
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.80 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 299.86s of the 449.89s of remaining time.
# 	0.5321	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 298.0s of the 448.03s of remaining time.
# 	0.5313	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 297.63s of the 447.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8644	 = Validation score   (roc_auc)
# 	1.72s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 286.17s of the 436.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	0.8588	 = Validation score   (roc_auc)
# 	3.03s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 280.12s of the 430.15s of remaining time.
# 	0.8449	 = Validation score   (roc_auc)
# 	1.53s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 278.15s of the 428.18s of remaining time.
# 	0.8534	 = Validation score   (roc_auc)
# 	1.48s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 276.26s of the 426.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.47%)
# 	0.8678	 = Validation score   (roc_auc)
# 	12.8s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 260.96s of the 410.99s of remaining time.
# 	0.8549	 = Validation score   (roc_auc)
# 	0.85s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 259.63s of the 409.66s of remaining time.
# 	0.8547	 = Validation score   (roc_auc)
# 	0.88s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 258.26s of the 408.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.8575	 = Validation score   (roc_auc)
# 	22.48s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 233.31s of the 383.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.73%)
# 	0.859	 = Validation score   (roc_auc)
# 	3.75s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 226.72s of the 376.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.8612	 = Validation score   (roc_auc)
# 	21.39s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 202.75s of the 352.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.62%)
# 	0.8521	 = Validation score   (roc_auc)
# 	5.2s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 195.03s of the 345.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.8643	 = Validation score   (roc_auc)
# 	9.8s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 182.53s of the 332.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.8595	 = Validation score   (roc_auc)
# 	30.64s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 149.39s of the 299.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.8591	 = Validation score   (roc_auc)
# 	4.73s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 142.13s of the 292.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# 	0.8606	 = Validation score   (roc_auc)
# 	63.44s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 76.18s of the 226.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.95%)
# 	0.8626	 = Validation score   (roc_auc)
# 	42.32s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 31.44s of the 181.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	0.8675	 = Validation score   (roc_auc)
# 	5.62s	 = Training   runtime
# 	0.97s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 22.95s of the 172.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.27%)
# 	0.8616	 = Validation score   (roc_auc)
# 	23.19s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 146.93s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.303, 'NeuralNetTorch_r79_BAG_L1': 0.182, 'LightGBM_r96_BAG_L1': 0.152, 'ExtraTreesGini_BAG_L1': 0.091, 'NeuralNetTorch_r22_BAG_L1': 0.091, 'ExtraTreesEntr_BAG_L1': 0.061, 'NeuralNetFastAI_BAG_L1': 0.061, 'NeuralNetFastAI_r191_BAG_L1': 0.061}
# 	0.872	 = Validation score   (roc_auc)
# 	3.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 143.78s of the 143.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8672	 = Validation score   (roc_auc)
# 	3.79s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 137.42s of the 137.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.64%)
# 	0.8635	 = Validation score   (roc_auc)
# 	4.1s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 130.5s of the 130.43s of remaining time.
# 	0.8527	 = Validation score   (roc_auc)
# 	2.57s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 127.48s of the 127.42s of remaining time.
# 	0.8579	 = Validation score   (roc_auc)
# 	2.64s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 124.41s of the 124.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8689	 = Validation score   (roc_auc)
# 	16.97s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 104.91s of the 104.85s of remaining time.
# 	0.8576	 = Validation score   (roc_auc)
# 	0.97s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 103.46s of the 103.4s of remaining time.
# 	0.8592	 = Validation score   (roc_auc)
# 	0.9s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 102.04s of the 101.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8639	 = Validation score   (roc_auc)
# 	23.26s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 76.19s of the 76.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.02%)
# 	0.863	 = Validation score   (roc_auc)
# 	5.42s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 67.9s of the 67.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.44%)
# 	0.8619	 = Validation score   (roc_auc)
# 	18.43s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 46.71s of the 46.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.96%)
# 	0.8609	 = Validation score   (roc_auc)
# 	8.17s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 35.82s of the 35.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.73%)
# 	0.8682	 = Validation score   (roc_auc)
# 	14.3s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 18.8s of the 18.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.8646	 = Validation score   (roc_auc)
# 	18.91s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -3.64s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.235, 'NeuralNetTorch_r79_BAG_L1': 0.133, 'LightGBMLarge_BAG_L2': 0.133, 'LightGBM_r96_BAG_L1': 0.122, 'ExtraTreesGini_BAG_L1': 0.082, 'NeuralNetTorch_r22_BAG_L1': 0.071, 'NeuralNetFastAI_BAG_L1': 0.061, 'NeuralNetFastAI_r191_BAG_L1': 0.061, 'ExtraTreesEntr_BAG_L1': 0.051, 'NeuralNetTorch_r79_BAG_L2': 0.041, 'CatBoost_BAG_L2': 0.01}
# 	0.8722	 = Validation score   (roc_auc)
# 	4.11s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 457.79s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240319_170823/ds_sub_fit/sub_fit_ho")
# Leaderboard on holdout data from dynamic stacking:
#                           model  holdout_score  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         NeuralNetTorch_BAG_L2       0.873614   0.861888     roc_auc        4.527886       5.485740  273.313112                 0.349788                0.278650          18.434801            2       True         31
# 1           LightGBM_r96_BAG_L1       0.869362   0.867532     roc_auc        0.298535       0.965180    5.617690                 0.298535                0.965180           5.617690            1       True         19
# 2           WeightedEnsemble_L3       0.868384   0.872239     roc_auc        4.733640       5.794621  303.039897                 0.007313                0.000000           4.111024            3       True         35
# 3     NeuralNetTorch_r79_BAG_L2       0.868088   0.864588     roc_auc        4.545925       5.645229  273.787014                 0.367827                0.438139          18.908703            2       True         34
# 4           WeightedEnsemble_L2       0.867960   0.872024     roc_auc        2.433630       3.105907  163.008360                 0.009110                0.000000           3.120656            2       True         21
# 5        NeuralNetFastAI_BAG_L2       0.867436   0.863873     roc_auc        4.494735       5.460572  278.139149                 0.316637                0.253482          23.260838            2       True         29
# 6               CatBoost_BAG_L2       0.867175   0.868897     roc_auc        4.247594       5.230140  271.847259                 0.069496                0.023051          16.968948            2       True         26
# 7     NeuralNetTorch_r22_BAG_L1       0.867097   0.861601     roc_auc        0.394268       0.465677   23.190371                 0.394268                0.465677          23.190371            1       True         20
# 8          CatBoost_r177_BAG_L2       0.867089   0.868211     roc_auc        4.261637       5.221876  269.175098                 0.083539                0.014786          14.296788            2       True         33
# 9             LightGBMXT_BAG_L1       0.866973   0.864412     roc_auc        0.194320       0.171243    1.723201                 0.194320                0.171243           1.723201            1       True          3
# 10        NeuralNetTorch_BAG_L1       0.866921   0.861233     roc_auc        0.268147       0.174139   21.388237                 0.268147                0.174139          21.388237            1       True         12
# 11           CatBoost_r9_BAG_L1       0.866900   0.862627     roc_auc        0.089947       0.046070   42.323025                 0.089947                0.046070          42.323025            1       True         18
# 12              LightGBM_BAG_L2       0.866716   0.863546     roc_auc        4.268629       5.264540  258.981468                 0.090531                0.057450           4.103157            2       True         23
# 13               XGBoost_BAG_L2       0.866711   0.863040     roc_auc        4.397655       5.268077  260.295569                 0.219557                0.060987           5.417259            2       True         30
# 14         LightGBM_r131_BAG_L1       0.866149   0.859082     roc_auc        0.180791       0.283554    4.733950                 0.180791                0.283554           4.733950            1       True         16
# 15         LightGBMLarge_BAG_L2       0.866046   0.860891     roc_auc        4.289003       5.333431  263.051222                 0.110906                0.126341           8.172912            2       True         32
# 16              CatBoost_BAG_L1       0.866008   0.867808     roc_auc        0.081939       0.060104   12.796780                 0.081939                0.060104          12.796780            1       True          7
# 17            LightGBMXT_BAG_L2       0.865296   0.867189     roc_auc        4.288718       5.297197  258.669255                 0.110620                0.090107           3.790944            2       True         22
# 18              LightGBM_BAG_L1       0.865210   0.858768     roc_auc        0.110234       0.074260    3.028121                 0.110234                0.074260           3.028121            1       True          4
# 19         CatBoost_r177_BAG_L1       0.865206   0.864306     roc_auc        0.090326       0.009697    9.799675                 0.090326                0.009697           9.799675            1       True         14
# 20  NeuralNetFastAI_r191_BAG_L1       0.862902   0.860649     roc_auc        0.444258       0.392169   63.436638                 0.444258                0.392169          63.436638            1       True         17
# 21       NeuralNetFastAI_BAG_L1       0.862434   0.857494     roc_auc        0.596998       0.253464   22.481312                 0.596998                0.253464          22.481312            1       True         10
# 22        ExtraTreesGini_BAG_L2       0.862042   0.857587     roc_auc        4.309818       5.554199  255.845938                 0.131720                0.347109           0.967628            2       True         27
# 23               XGBoost_BAG_L1       0.861645   0.858972     roc_auc        0.242846       0.065260    3.749452                 0.242846                0.065260           3.749452            1       True         11
# 24        ExtraTreesEntr_BAG_L2       0.860933   0.859151     roc_auc        4.305810       5.583267  255.780347                 0.127712                0.376177           0.902036            2       True         28
# 25        ExtraTreesEntr_BAG_L1       0.860362   0.854702     roc_auc        0.159896       0.351333    0.876355                 0.159896                0.351333           0.876355            1       True          9
# 26    NeuralNetTorch_r79_BAG_L1       0.860324   0.859504     roc_auc        0.298723       0.272187   30.641757                 0.298723                0.272187          30.641757            1       True         15
# 27         LightGBMLarge_BAG_L1       0.860139   0.852080     roc_auc        0.120433       0.101993    5.200888                 0.120433                0.101993           5.200888            1       True         13
# 28      RandomForestGini_BAG_L2       0.856581   0.852720     roc_auc        4.319288       5.519481  257.443944                 0.141191                0.312391           2.565633            2       True         24
# 29      RandomForestEntr_BAG_L2       0.856042   0.857864     roc_auc        4.280041       5.513978  257.516303                 0.101943                0.306888           2.637992            2       True         25
# 30      RandomForestEntr_BAG_L1       0.855066   0.853374     roc_auc        0.150108       0.284240    1.483447                 0.150108                0.284240           1.483447            1       True          6
# 31        ExtraTreesGini_BAG_L1       0.853758   0.854901     roc_auc        0.149904       0.345792    0.846801                 0.149904                0.345792           0.846801            1       True          8
# 32      RandomForestGini_BAG_L1       0.845201   0.844905     roc_auc        0.188399       0.306392    1.527866                 0.188399                0.306392           1.527866            1       True          5
# 33        KNeighborsUnif_BAG_L1       0.563090   0.532084     roc_auc        0.062644       0.283167    0.010274                 0.062644                0.283167           0.010274            1       True          1
# 34        KNeighborsDist_BAG_L1       0.561130   0.531307     roc_auc        0.055382       0.301167    0.022471                 0.055382                0.301167           0.022471            1       True          2
# Stacked overfitting occurred: False.
# Spend 465 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 1335 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 1335s
# AutoGluon will save models to "AutogluonModels\ag-20240319_170823"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.9.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       6.61 GB / 15.63 GB (42.3%)
# Disk Space Avail:   162.85 GB / 241.59 GB (67.4%)
# ===================================================
# Train Data Rows:    16336
# Train Data Columns: 27
# Label Column:       Pastry
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6762.49 MB
# 	Train Data (Original)  Memory Usage: 3.37 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 14 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  2 | ['TypeOfSteel_A300', 'TypeOfSteel_A400']
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.15 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 889.69s of the 1334.86s of remaining time.
# 	0.5393	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 889.27s of the 1334.44s of remaining time.
# 	0.5396	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 888.85s of the 1334.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# 	0.8647	 = Validation score   (roc_auc)
# 	1.68s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 880.72s of the 1325.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	0.8628	 = Validation score   (roc_auc)
# 	3.49s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 874.37s of the 1319.54s of remaining time.
# 	0.8438	 = Validation score   (roc_auc)
# 	1.67s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 872.25s of the 1317.42s of remaining time.
# 	0.853	 = Validation score   (roc_auc)
# 	1.69s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 870.14s of the 1315.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.47%)
# 	0.8661	 = Validation score   (roc_auc)
# 	13.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 854.62s of the 1299.79s of remaining time.
# 	0.8532	 = Validation score   (roc_auc)
# 	0.91s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 853.13s of the 1298.3s of remaining time.
# 	0.8532	 = Validation score   (roc_auc)
# 	0.9s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 851.74s of the 1296.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8608	 = Validation score   (roc_auc)
# 	23.36s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 825.89s of the 1271.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8601	 = Validation score   (roc_auc)
# 	4.31s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 818.95s of the 1264.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8594	 = Validation score   (roc_auc)
# 	22.22s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 794.14s of the 1239.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.64%)
# 	0.8572	 = Validation score   (roc_auc)
# 	5.1s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 786.53s of the 1231.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8658	 = Validation score   (roc_auc)
# 	10.4s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 773.55s of the 1218.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8605	 = Validation score   (roc_auc)
# 	34.74s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 736.36s of the 1181.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	0.8624	 = Validation score   (roc_auc)
# 	4.62s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 729.17s of the 1174.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.62%)
# 	0.8611	 = Validation score   (roc_auc)
# 	73.31s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 653.14s of the 1098.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.94%)
# 	0.8644	 = Validation score   (roc_auc)
# 	43.27s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 607.36s of the 1052.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.8674	 = Validation score   (roc_auc)
# 	6.03s	 = Training   runtime
# 	1.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 598.55s of the 1043.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8605	 = Validation score   (roc_auc)
# 	53.97s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 541.79s of the 986.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.66%)
# 	0.8589	 = Validation score   (roc_auc)
# 	10.1s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 529.16s of the 974.33s of remaining time.
# 	0.8497	 = Validation score   (roc_auc)
# 	1.16s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 527.51s of the 972.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8664	 = Validation score   (roc_auc)
# 	9.8s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 515.25s of the 960.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8616	 = Validation score   (roc_auc)
# 	12.37s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 500.36s of the 945.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.28%)
# 	0.8675	 = Validation score   (roc_auc)
# 	43.72s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 453.58s of the 898.75s of remaining time.
# 	0.8367	 = Validation score   (roc_auc)
# 	5.8s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 447.34s of the 892.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8623	 = Validation score   (roc_auc)
# 	4.2s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 440.44s of the 885.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8627	 = Validation score   (roc_auc)
# 	52.78s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 384.87s of the 830.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8642	 = Validation score   (roc_auc)
# 	4.08s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 377.92s of the 823.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.8602	 = Validation score   (roc_auc)
# 	67.98s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 307.02s of the 752.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.861	 = Validation score   (roc_auc)
# 	3.59s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 300.67s of the 745.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.8549	 = Validation score   (roc_auc)
# 	31.76s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 266.01s of the 711.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.8676	 = Validation score   (roc_auc)
# 	8.01s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 255.29s of the 700.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8579	 = Validation score   (roc_auc)
# 	86.62s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 165.89s of the 611.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.73%)
# 	0.8575	 = Validation score   (roc_auc)
# 	3.75s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 159.8s of the 604.97s of remaining time.
# 	0.8586	 = Validation score   (roc_auc)
# 	1.19s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 158.21s of the 603.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# 	0.8668	 = Validation score   (roc_auc)
# 	8.24s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 147.68s of the 592.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8609	 = Validation score   (roc_auc)
# 	36.91s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 108.34s of the 553.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8618	 = Validation score   (roc_auc)
# 	11.81s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 94.1s of the 539.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.91%)
# 	0.8564	 = Validation score   (roc_auc)
# 	6.92s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 84.49s of the 529.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# 	0.8611	 = Validation score   (roc_auc)
# 	15.96s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 66.0s of the 511.17s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.8647	 = Validation score   (roc_auc)
# 	17.8s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 45.54s of the 490.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8574	 = Validation score   (roc_auc)
# 	16.65s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 26.51s of the 471.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.72%)
# 	0.8646	 = Validation score   (roc_auc)
# 	9.02s	 = Training   runtime
# 	2.81s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 13.69s of the 458.86s of remaining time.
# 	0.8426	 = Validation score   (roc_auc)
# 	5.31s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 7.96s of the 453.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# 	0.8661	 = Validation score   (roc_auc)
# 	8.01s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 442.41s of remaining time.
# 	Ensemble Weights: {'CatBoost_r50_BAG_L1': 0.18, 'LightGBM_r96_BAG_L1': 0.112, 'ExtraTrees_r172_BAG_L1': 0.101, 'CatBoost_r69_BAG_L1': 0.101, 'NeuralNetFastAI_r145_BAG_L1': 0.09, 'NeuralNetTorch_r79_BAG_L1': 0.079, 'NeuralNetTorch_r14_BAG_L1': 0.079, 'NeuralNetFastAI_r191_BAG_L1': 0.067, 'CatBoost_r167_BAG_L1': 0.056, 'LightGBM_BAG_L1': 0.045, 'NeuralNetTorch_r22_BAG_L1': 0.022, 'NeuralNetFastAI_r102_BAG_L1': 0.022, 'NeuralNetTorch_r30_BAG_L1': 0.022, 'NeuralNetFastAI_r103_BAG_L1': 0.022}
# 	0.8718	 = Validation score   (roc_auc)
# 	4.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 438.37s of the 438.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.77%)
# 	0.8649	 = Validation score   (roc_auc)
# 	3.75s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 432.27s of the 432.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.91%)
# 	0.8643	 = Validation score   (roc_auc)
# 	4.74s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 424.87s of the 424.75s of remaining time.
# 	0.8541	 = Validation score   (roc_auc)
# 	4.03s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 420.26s of the 420.14s of remaining time.
# 	0.8615	 = Validation score   (roc_auc)
# 	4.08s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 415.6s of the 415.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.97%)
# 	0.8688	 = Validation score   (roc_auc)
# 	17.67s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 395.56s of the 395.44s of remaining time.
# 	0.8596	 = Validation score   (roc_auc)
# 	0.9s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 394.02s of the 393.9s of remaining time.
# 	0.8616	 = Validation score   (roc_auc)
# 	0.92s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 392.5s of the 392.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.97%)
# 	0.8656	 = Validation score   (roc_auc)
# 	22.91s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 367.19s of the 367.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.28%)
# 	0.8626	 = Validation score   (roc_auc)
# 	6.65s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 358.04s of the 357.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8658	 = Validation score   (roc_auc)
# 	16.67s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 338.56s of the 338.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.43%)
# 	0.8614	 = Validation score   (roc_auc)
# 	10.24s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 325.82s of the 325.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.99%)
# 	0.8681	 = Validation score   (roc_auc)
# 	18.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 305.19s of the 305.07s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.53%)
# 	0.8655	 = Validation score   (roc_auc)
# 	39.51s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 263.04s of the 262.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.91%)
# 	0.8658	 = Validation score   (roc_auc)
# 	7.0s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 253.62s of the 253.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.00%)
# 	0.8672	 = Validation score   (roc_auc)
# 	61.45s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 189.76s of the 189.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.15%)
# 	0.8674	 = Validation score   (roc_auc)
# 	78.23s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 109.11s of the 108.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.66%)
# 	0.868	 = Validation score   (roc_auc)
# 	4.57s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 102.08s of the 101.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.8651	 = Validation score   (roc_auc)
# 	50.94s	 = Training   runtime
# 	0.7s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 48.67s of the 48.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.95%)
# 	0.8622	 = Validation score   (roc_auc)
# 	18.72s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 27.4s of the 27.28s of remaining time.
# 	0.8575	 = Validation score   (roc_auc)
# 	2.24s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 24.57s of the 24.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.8686	 = Validation score   (roc_auc)
# 	10.6s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 11.56s of the 11.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.98%)
# 	0.867	 = Validation score   (roc_auc)
# 	13.56s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -5.85s of remaining time.
# 	Ensemble Weights: {'CatBoost_r50_BAG_L1': 0.246, 'NeuralNetTorch_r79_BAG_L2': 0.123, 'LightGBM_r96_BAG_L1': 0.105, 'NeuralNetFastAI_r145_BAG_L1': 0.105, 'NeuralNetTorch_r14_BAG_L1': 0.088, 'NeuralNetTorch_r79_BAG_L1': 0.07, 'RandomForestEntr_BAG_L2': 0.07, 'NeuralNetTorch_r22_BAG_L2': 0.07, 'NeuralNetFastAI_r102_BAG_L1': 0.053, 'CatBoost_r177_BAG_L2': 0.053, 'CatBoost_BAG_L2': 0.018}
# 	0.8718	 = Validation score   (roc_auc)
# 	4.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1344.94s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240319_170823")

# %%
dirtiness_predictor.evaluate(xtrain_dirtiness)
# Out:
# {'roc_auc': 0.9310208306075798,
#  'accuracy': 0.9292972575905974,
#  'balanced_accuracy': 0.5416709480942064,
#  'mcc': 0.2601406848662326,
#  'f1': 0.15384615384615385,
#  'precision': 0.8823529411764706,
#  'recall': 0.08426966292134831}

# %%
dirtiness_predictor.evaluate(xtest_dirtiness)
# Out:
# {'roc_auc': 0.8849383811832179,
#  'accuracy': 0.9240374609781478,
#  'balanced_accuracy': 0.5147825419042091,
#  'mcc': 0.1171556973782576,
#  'f1': 0.060085836909871244,
#  'precision': 0.5384615384615384,
#  'recall': 0.031818181818181815}

# %%
xtr_bumps, xte_bumps, ytr_bumps, yte_bumps = train_test_split(X,bumps,test_size=0.05, stratify=bumps, random_state=0)

# %%
xtrain_bumps = pd.concat([xtr_bumps,ytr_bumps], axis=1)
xtest_bumps = pd.concat([xte_bumps,yte_bumps], axis=1)

# %%
bumps_predictor = TabularPredictor(label='Bumps', eval_metric='roc_auc')
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240319_235904"

# %%
bumps_predictor.fit(xtrain_bumps, time_limit=3600, presets='best_quality')
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 3600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240319_235904/ds_sub_fit/sub_fit_ho.
# Beginning AutoGluon training ... Time limit = 900s
# AutoGluon will save models to "AutogluonModels\ag-20240319_235904/ds_sub_fit/sub_fit_ho"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.9.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       8.07 GB / 15.63 GB (51.6%)
# Disk Space Avail:   161.78 GB / 241.59 GB (67.0%)
# ===================================================
# Train Data Rows:    17868
# Train Data Columns: 27
# Label Column:       Pastry
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8261.02 MB
# 	Train Data (Original)  Memory Usage: 3.68 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 14 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  2 | ['TypeOfSteel_A300', 'TypeOfSteel_A400']
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.44 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 599.8s of the 899.9s of remaining time.
# 	0.5383	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 595.08s of the 895.19s of remaining time.
# 	0.5393	 = Validation score   (roc_auc)
# 	0.03s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 594.71s of the 894.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8792	 = Validation score   (roc_auc)
# 	1.39s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 581.59s of the 881.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.8762	 = Validation score   (roc_auc)
# 	2.55s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 576.81s of the 876.92s of remaining time.
# 	0.8614	 = Validation score   (roc_auc)
# 	1.42s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 574.86s of the 874.97s of remaining time.
# 	0.8672	 = Validation score   (roc_auc)
# 	1.42s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 572.93s of the 873.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.8804	 = Validation score   (roc_auc)
# 	9.49s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 561.47s of the 861.58s of remaining time.
# 	0.8653	 = Validation score   (roc_auc)
# 	0.79s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 560.1s of the 860.21s of remaining time.
# 	0.8691	 = Validation score   (roc_auc)
# 	0.78s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 558.73s of the 858.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.8698	 = Validation score   (roc_auc)
# 	22.51s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 534.18s of the 834.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.8746	 = Validation score   (roc_auc)
# 	3.43s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 528.0s of the 828.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8732	 = Validation score   (roc_auc)
# 	20.56s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 505.15s of the 805.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# 	0.8714	 = Validation score   (roc_auc)
# 	4.63s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 498.09s of the 798.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	0.8778	 = Validation score   (roc_auc)
# 	8.68s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 487.03s of the 787.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.8721	 = Validation score   (roc_auc)
# 	41.81s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 442.89s of the 743.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.41%)
# 	0.8764	 = Validation score   (roc_auc)
# 	4.52s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 435.98s of the 736.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.8726	 = Validation score   (roc_auc)
# 	74.2s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 359.47s of the 659.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.82%)
# 	0.8801	 = Validation score   (roc_auc)
# 	41.47s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 315.81s of the 615.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.8805	 = Validation score   (roc_auc)
# 	5.61s	 = Training   runtime
# 	1.28s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 307.66s of the 607.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.8745	 = Validation score   (roc_auc)
# 	71.33s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 233.72s of the 533.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.40%)
# 	0.8743	 = Validation score   (roc_auc)
# 	10.52s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 220.56s of the 520.67s of remaining time.
# 	0.8652	 = Validation score   (roc_auc)
# 	1.21s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 218.79s of the 518.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	0.8787	 = Validation score   (roc_auc)
# 	9.12s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 207.22s of the 507.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	0.8739	 = Validation score   (roc_auc)
# 	13.89s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 190.66s of the 490.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.99%)
# 	0.8806	 = Validation score   (roc_auc)
# 	52.28s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 135.32s of the 435.43s of remaining time.
# 	0.8525	 = Validation score   (roc_auc)
# 	5.66s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 129.11s of the 429.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# 	0.8755	 = Validation score   (roc_auc)
# 	4.6s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 121.81s of the 421.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.50%)
# 	0.8731	 = Validation score   (roc_auc)
# 	59.19s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 60.03s of the 360.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8771	 = Validation score   (roc_auc)
# 	3.84s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 53.16s of the 353.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# 	0.8651	 = Validation score   (roc_auc)
# 	45.92s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 4.54s of the 304.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.8749	 = Validation score   (roc_auc)
# 	3.72s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 297.75s of remaining time.
# 	Ensemble Weights: {'CatBoost_r9_BAG_L1': 0.18, 'CatBoost_BAG_L1': 0.14, 'LightGBMXT_BAG_L1': 0.1, 'NeuralNetTorch_r79_BAG_L1': 0.08, 'LightGBM_r96_BAG_L1': 0.08, 'NeuralNetTorch_BAG_L1': 0.07, 'CatBoost_r137_BAG_L1': 0.07, 'LightGBM_BAG_L1': 0.06, 'NeuralNetTorch_r22_BAG_L1': 0.06, 'ExtraTreesEntr_BAG_L1': 0.05, 'ExtraTrees_r42_BAG_L1': 0.05, 'NeuralNetFastAI_r145_BAG_L1': 0.04, 'NeuralNetFastAI_r102_BAG_L1': 0.01, 'CatBoost_r13_BAG_L1': 0.01}
# 	0.8838	 = Validation score   (roc_auc)
# 	4.35s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 293.37s of the 293.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.8808	 = Validation score   (roc_auc)
# 	4.21s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 286.87s of the 286.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8794	 = Validation score   (roc_auc)
# 	4.75s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 279.32s of the 279.23s of remaining time.
# 	0.8702	 = Validation score   (roc_auc)
# 	3.84s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 274.82s of the 274.73s of remaining time.
# 	0.8726	 = Validation score   (roc_auc)
# 	3.8s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 270.36s of the 270.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.71%)
# 	0.8819	 = Validation score   (roc_auc)
# 	17.05s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 250.76s of the 250.67s of remaining time.
# 	0.8723	 = Validation score   (roc_auc)
# 	0.94s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 249.07s of the 248.99s of remaining time.
# 	0.8769	 = Validation score   (roc_auc)
# 	0.95s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 247.44s of the 247.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.77%)
# 	0.8803	 = Validation score   (roc_auc)
# 	28.17s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 216.69s of the 216.6s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.03%)
# 	0.8756	 = Validation score   (roc_auc)
# 	6.27s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 207.5s of the 207.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	0.8807	 = Validation score   (roc_auc)
# 	23.42s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 181.19s of the 181.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.00%)
# 	0.8757	 = Validation score   (roc_auc)
# 	9.05s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 169.52s of the 169.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.76%)
# 	0.8812	 = Validation score   (roc_auc)
# 	13.25s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 153.52s of the 153.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.8704	 = Validation score   (roc_auc)
# 	36.53s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 114.23s of the 114.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8801	 = Validation score   (roc_auc)
# 	7.04s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 104.43s of the 104.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.81%)
# 	0.88	 = Validation score   (roc_auc)
# 	84.06s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 17.58s of the 17.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.54%)
# 	0.8812	 = Validation score   (roc_auc)
# 	15.64s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -1.51s of remaining time.
# 	Ensemble Weights: {'NeuralNetTorch_BAG_L2': 0.208, 'CatBoost_BAG_L1': 0.17, 'LightGBM_BAG_L2': 0.113, 'LightGBMXT_BAG_L1': 0.094, 'ExtraTreesEntr_BAG_L2': 0.094, 'NeuralNetTorch_r22_BAG_L1': 0.075, 'NeuralNetTorch_BAG_L1': 0.038, 'CatBoost_BAG_L2': 0.038, 'NeuralNetFastAI_BAG_L2': 0.038, 'LightGBM_r131_BAG_L2': 0.038, 'NeuralNetFastAI_r191_BAG_L2': 0.038, 'LightGBM_r96_BAG_L1': 0.019, 'NeuralNetFastAI_r145_BAG_L1': 0.019, 'LightGBMXT_BAG_L2': 0.019}
# 	0.8841	 = Validation score   (roc_auc)
# 	4.29s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 905.83s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240319_235904/ds_sub_fit/sub_fit_ho")
# Leaderboard on holdout data from dynamic stacking:
#                           model  holdout_score  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         ExtraTreesGini_BAG_L2       0.886075   0.872285     roc_auc        6.168901       9.615628  527.536743                 0.139452                0.597560           0.939641            2       True         38
# 1           CatBoost_r13_BAG_L1       0.882981   0.880568     roc_auc        0.079700       0.021796   52.279622                 0.079700                0.021796          52.279622            1       True         25
# 2               CatBoost_BAG_L1       0.882216   0.880400     roc_auc        0.070155       0.023550    9.486506                 0.070155                0.023550           9.486506            1       True          7
# 3         ExtraTreesEntr_BAG_L2       0.881724   0.876928     roc_auc        6.166894       9.559421  527.550747                 0.137444                0.541353           0.953644            2       True         39
# 4           WeightedEnsemble_L2       0.881300   0.883821     roc_auc        2.793190       4.007383  335.042710                 0.015615                0.000000           4.353752            2       True         32
# 5     NeuralNetTorch_r79_BAG_L2       0.881261   0.870350     roc_auc        6.454637       9.523753  563.123564                 0.425187                0.505685          36.526461            2       True         45
# 6          CatBoost_r177_BAG_L1       0.880748   0.877778     roc_auc        0.076017       0.006998    8.683343                 0.076017                0.006998           8.683343            1       True         14
# 7       RandomForestEntr_BAG_L2       0.880385   0.872607     roc_auc        6.126806       9.559780  530.397282                 0.097357                0.541711           3.800179            2       True         36
# 8           WeightedEnsemble_L3       0.880335   0.884130     roc_auc        7.768425      11.292774  700.545946                 0.007060                0.004205           4.294727            3       True         49
# 9   NeuralNetFastAI_r191_BAG_L2       0.880005   0.880032     roc_auc        6.473518       9.491831  610.656833                 0.444069                0.473763          84.059730            2       True         47
# 10       NeuralNetFastAI_BAG_L2       0.879863   0.880308     roc_auc        6.349186       9.307555  554.767097                 0.319737                0.289486          28.169994            2       True         40
# 11         CatBoost_r137_BAG_L1       0.879220   0.878721     roc_auc        0.069793       0.021118    9.117200                 0.069793                0.021118           9.117200            1       True         23
# 12        ExtraTreesGini_BAG_L1       0.878836   0.865331     roc_auc        0.149536       0.437159    0.791780                 0.149536                0.437159           0.791780            1       True          8
# 13          LightGBM_r96_BAG_L1       0.878681   0.880512     roc_auc        0.312201       1.279613    5.612621                 0.312201                1.279613           5.612621            1       True         19
# 14            LightGBMXT_BAG_L1       0.877953   0.879194     roc_auc        0.117598       0.138067    1.388801                 0.117598                0.138067           1.388801            1       True          3
# 15  NeuralNetFastAI_r145_BAG_L1       0.877902   0.873087     roc_auc        0.535821       0.506605   59.192522                 0.535821                0.506605          59.192522            1       True         28
# 16              CatBoost_BAG_L2       0.877831   0.881917     roc_auc        6.099073       9.052424  543.650275                 0.069623                0.034356          17.053172            2       True         37
# 17         LightGBM_r131_BAG_L2       0.877729   0.880114     roc_auc        6.182606       9.350170  533.637658                 0.153157                0.332101           7.040556            2       True         46
# 18               XGBoost_BAG_L2       0.877706   0.875649     roc_auc        6.223950       9.131317  532.862148                 0.194501                0.113249           6.265045            2       True         41
# 19           CatBoost_r9_BAG_L2       0.877576   0.881162     roc_auc        6.123221       9.056681  542.241074                 0.093772                0.038613          15.643971            2       True         48
# 20  NeuralNetFastAI_r102_BAG_L1       0.877573   0.873891     roc_auc        0.208187       0.162838   13.893986                 0.208187                0.162838          13.893986            1       True         24
# 21         CatBoost_r177_BAG_L2       0.877080   0.881196     roc_auc        6.115743       9.035885  539.846204                 0.086293                0.017817          13.249101            2       True         44
# 22           CatBoost_r9_BAG_L1       0.876932   0.880114     roc_auc        0.094117       0.045573   41.472841                 0.094117                0.045573          41.472841            1       True         18
# 23            LightGBMXT_BAG_L2       0.876739   0.880811     roc_auc        6.161368       9.156579  530.811756                 0.131919                0.138510           4.214653            2       True         33
# 24              LightGBM_BAG_L2       0.876569   0.879394     roc_auc        6.131878       9.091086  531.343797                 0.102429                0.073017           4.746694            2       True         34
# 25  NeuralNetFastAI_r191_BAG_L1       0.876521   0.872592     roc_auc        0.413093       0.408375   74.197654                 0.413093                0.408375          74.197654            1       True         17
# 26        ExtraTreesEntr_BAG_L1       0.876460   0.869131     roc_auc        0.146610       0.443194    0.777706                 0.146610                0.443194           0.777706            1       True          9
# 27      RandomForestGini_BAG_L2       0.876330   0.870204     roc_auc        6.175297       9.538392  530.432986                 0.145848                0.520324           3.835883            2       True         35
# 28         LightGBMLarge_BAG_L2       0.876147   0.875682     roc_auc        6.129883       9.138606  535.643606                 0.100434                0.120538           9.046503            2       True         43
# 29    NeuralNetTorch_r30_BAG_L1       0.876085   0.865067     roc_auc        0.409509       0.507041   45.924040                 0.409509                0.507041          45.924040            1       True         30
# 30         LightGBM_r130_BAG_L1       0.875895   0.874853     roc_auc        0.097383       0.156948    3.721794                 0.097383                0.156948           3.721794            1       True         31
# 31         LightGBM_r188_BAG_L1       0.875447   0.875508     roc_auc        0.162367       0.281671    4.603788                 0.162367                0.281671           4.603788            1       True         27
# 32    NeuralNetTorch_r79_BAG_L1       0.875263   0.872129     roc_auc        0.277132       0.245018   41.808169                 0.277132                0.245018          41.808169            1       True         15
# 33    NeuralNetTorch_r22_BAG_L1       0.875243   0.874470     roc_auc        0.360991       0.460422   71.334427                 0.360991                0.460422          71.334427            1       True         20
# 34       NeuralNetFastAI_BAG_L1       0.874888   0.869829     roc_auc        0.448457       0.239393   22.505132                 0.448457                0.239393          22.505132            1       True         10
# 35           XGBoost_r89_BAG_L1       0.873412   0.877127     roc_auc        0.179844       0.116353    3.835121                 0.179844                0.116353           3.835121            1       True         29
# 36              LightGBM_BAG_L1       0.872845   0.876230     roc_auc        0.090186       0.092776    2.551873                 0.090186                0.092776           2.551873            1       True          4
# 37        NeuralNetTorch_BAG_L2       0.872711   0.880659     roc_auc        6.402986       9.405982  550.012776                 0.373537                0.387913          23.415673            2       True         42
# 38               XGBoost_BAG_L1       0.872442   0.874569     roc_auc        0.182594       0.069535    3.430156                 0.182594                0.069535           3.430156            1       True         11
# 39         LightGBMLarge_BAG_L1       0.872110   0.871425     roc_auc        0.110489       0.151481    4.626272                 0.110489                0.151481           4.626272            1       True         13
# 40           XGBoost_r33_BAG_L1       0.871943   0.874338     roc_auc        0.369906       0.391560   10.519028                 0.369906                0.391560          10.519028            1       True         21
# 41        ExtraTrees_r42_BAG_L1       0.871861   0.865187     roc_auc        0.164536       0.419793    1.213027                 0.164536                0.419793           1.213027            1       True         22
# 42         LightGBM_r131_BAG_L1       0.871770   0.876379     roc_auc        0.167480       0.412121    4.520247                 0.167480                0.412121           4.520247            1       True         16
# 43        NeuralNetTorch_BAG_L1       0.870027   0.873242     roc_auc        0.250550       0.147019   20.559657                 0.250550                0.147019          20.559657            1       True         12
# 44      RandomForestEntr_BAG_L1       0.868240   0.867192     roc_auc        0.107049       0.382377    1.421225                 0.107049                0.382377           1.421225            1       True          6
# 45      RandomForestGini_BAG_L1       0.864563   0.861442     roc_auc        0.145463       0.405813    1.421673                 0.145463                0.405813           1.421673            1       True          5
# 46     RandomForest_r195_BAG_L1       0.854246   0.852451     roc_auc        0.104702       0.416820    5.663337                 0.104702                0.416820           5.663337            1       True         26
# 47        KNeighborsUnif_BAG_L1       0.583097   0.538270     roc_auc        0.064108       0.319164    0.015737                 0.064108                0.319164           0.015737            1       True          1
# 48        KNeighborsDist_BAG_L1       0.578165   0.539345     roc_auc        0.063878       0.307874    0.027819                 0.063878                0.307874           0.027819            1       True          2
# Stacked overfitting occurred: True.
# Spend 916 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 2684 seconds.
# Starting full fit now with num_stack_levels 0.
# Beginning AutoGluon training ... Time limit = 2684s
# AutoGluon will save models to "AutogluonModels\ag-20240319_235904"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.9.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       8.06 GB / 15.63 GB (51.6%)
# Disk Space Avail:   161.78 GB / 241.59 GB (67.0%)
# ===================================================
# Train Data Rows:    20102
# Train Data Columns: 27
# Label Column:       Pastry
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8254.76 MB
# 	Train Data (Original)  Memory Usage: 4.14 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 14 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  2 | ['TypeOfSteel_A300', 'TypeOfSteel_A400']
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.87 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2683.9s of the 2683.89s of remaining time.
# 	0.5379	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2683.26s of the 2683.25s of remaining time.
# 	0.5396	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2682.65s of the 2682.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# 	0.8794	 = Validation score   (roc_auc)
# 	3.06s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2677.17s of the 2677.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# 	0.8768	 = Validation score   (roc_auc)
# 	2.88s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2671.79s of the 2671.78s of remaining time.
# 	0.8614	 = Validation score   (roc_auc)
# 	1.99s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2669.24s of the 2669.23s of remaining time.
# 	0.8684	 = Validation score   (roc_auc)
# 	1.89s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2666.81s of the 2666.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	0.8821	 = Validation score   (roc_auc)
# 	14.16s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2650.35s of the 2650.35s of remaining time.
# 	0.8677	 = Validation score   (roc_auc)
# 	0.9s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2648.85s of the 2648.85s of remaining time.
# 	0.8702	 = Validation score   (roc_auc)
# 	0.86s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2647.37s of the 2647.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.873	 = Validation score   (roc_auc)
# 	25.68s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2619.47s of the 2619.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8752	 = Validation score   (roc_auc)
# 	3.48s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2613.46s of the 2613.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	0.8721	 = Validation score   (roc_auc)
# 	24.09s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2586.86s of the 2586.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# 	0.8725	 = Validation score   (roc_auc)
# 	5.2s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 2579.11s of the 2579.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# 	0.8801	 = Validation score   (roc_auc)
# 	11.81s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 2564.59s of the 2564.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8702	 = Validation score   (roc_auc)
# 	36.41s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 2525.72s of the 2525.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.8781	 = Validation score   (roc_auc)
# 	4.59s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 2518.62s of the 2518.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	0.8751	 = Validation score   (roc_auc)
# 	82.42s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 2433.68s of the 2433.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.88%)
# 	0.879	 = Validation score   (roc_auc)
# 	36.26s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 2394.85s of the 2394.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.8817	 = Validation score   (roc_auc)
# 	6.3s	 = Training   runtime
# 	1.73s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 2385.78s of the 2385.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8734	 = Validation score   (roc_auc)
# 	71.35s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 2311.95s of the 2311.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.45%)
# 	0.8748	 = Validation score   (roc_auc)
# 	9.78s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 2299.68s of the 2299.67s of remaining time.
# 	0.8641	 = Validation score   (roc_auc)
# 	1.31s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 2297.8s of the 2297.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8818	 = Validation score   (roc_auc)
# 	10.99s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 2284.28s of the 2284.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8736	 = Validation score   (roc_auc)
# 	14.17s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 2267.81s of the 2267.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.08%)
# 	0.8812	 = Validation score   (roc_auc)
# 	53.68s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 2211.01s of the 2211.0s of remaining time.
# 	0.8537	 = Validation score   (roc_auc)
# 	6.54s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 2203.87s of the 2203.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.877	 = Validation score   (roc_auc)
# 	5.31s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 2195.76s of the 2195.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# 	0.8754	 = Validation score   (roc_auc)
# 	59.15s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 2133.8s of the 2133.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8795	 = Validation score   (roc_auc)
# 	3.66s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 2126.87s of the 2126.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.8705	 = Validation score   (roc_auc)
# 	75.31s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 2048.68s of the 2048.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# ...
# 	23.11s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: XGBoost_r98_BAG_L1 ... Training model for up to 1576.51s of the 1576.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.91%)
# 	0.8785	 = Validation score   (roc_auc)
# 	13.77s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: LightGBM_r15_BAG_L1 ... Training model for up to 1560.41s of the 1560.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.8791	 = Validation score   (roc_auc)
# 	3.66s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 1554.26s of the 1554.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.8592	 = Validation score   (roc_auc)
# 	285.37s	 = Training   runtime
# 	1.34s	 = Validation runtime
# Fitting model: CatBoost_r86_BAG_L1 ... Training model for up to 1266.26s of the 1266.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.84%)
# 	0.8795	 = Validation score   (roc_auc)
# 	26.18s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37_BAG_L1 ... Training model for up to 1237.83s of the 1237.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8744	 = Validation score   (roc_auc)
# 	35.64s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197_BAG_L1 ... Training model for up to 1199.9s of the 1199.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.8724	 = Validation score   (roc_auc)
# 	18.61s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: CatBoost_r49_BAG_L1 ... Training model for up to 1178.76s of the 1178.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.881	 = Validation score   (roc_auc)
# 	7.97s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r49_BAG_L1 ... Training model for up to 1168.53s of the 1168.53s of remaining time.
# 	0.8677	 = Validation score   (roc_auc)
# 	1.0s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: LightGBM_r143_BAG_L1 ... Training model for up to 1166.89s of the 1166.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.871	 = Validation score   (roc_auc)
# 	7.14s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: RandomForest_r127_BAG_L1 ... Training model for up to 1157.23s of the 1157.22s of remaining time.
# 	0.8631	 = Validation score   (roc_auc)
# 	7.49s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134_BAG_L1 ... Training model for up to 1149.23s of the 1149.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8712	 = Validation score   (roc_auc)
# 	64.1s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: RandomForest_r34_BAG_L1 ... Training model for up to 1082.68s of the 1082.67s of remaining time.
# 	0.8705	 = Validation score   (roc_auc)
# 	4.39s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: LightGBM_r94_BAG_L1 ... Training model for up to 1077.81s of the 1077.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8806	 = Validation score   (roc_auc)
# 	3.62s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143_BAG_L1 ... Training model for up to 1071.52s of the 1071.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8747	 = Validation score   (roc_auc)
# 	92.13s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: CatBoost_r128_BAG_L1 ... Training model for up to 977.01s of the 977.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.83%)
# 	0.8783	 = Validation score   (roc_auc)
# 	33.92s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111_BAG_L1 ... Training model for up to 940.81s of the 940.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.875	 = Validation score   (roc_auc)
# 	17.28s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31_BAG_L1 ... Training model for up to 921.16s of the 921.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# 	0.875	 = Validation score   (roc_auc)
# 	36.04s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: ExtraTrees_r4_BAG_L1 ... Training model for up to 882.35s of the 882.34s of remaining time.
# 	0.8738	 = Validation score   (roc_auc)
# 	1.08s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65_BAG_L1 ... Training model for up to 880.8s of the 880.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8689	 = Validation score   (roc_auc)
# 	21.65s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r88_BAG_L1 ... Training model for up to 856.81s of the 856.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.71%)
# 	0.8743	 = Validation score   (roc_auc)
# 	23.51s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_r30_BAG_L1 ... Training model for up to 830.64s of the 830.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.8782	 = Validation score   (roc_auc)
# 	7.47s	 = Training   runtime
# 	1.38s	 = Validation runtime
# Fitting model: XGBoost_r49_BAG_L1 ... Training model for up to 820.29s of the 820.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8764	 = Validation score   (roc_auc)
# 	5.6s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: CatBoost_r5_BAG_L1 ... Training model for up to 812.15s of the 812.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# 	0.8815	 = Validation score   (roc_auc)
# 	13.31s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r87_BAG_L1 ... Training model for up to 796.22s of the 796.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8708	 = Validation score   (roc_auc)
# 	35.68s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_r71_BAG_L1 ... Training model for up to 758.19s of the 758.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	0.8732	 = Validation score   (roc_auc)
# 	10.7s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r143_BAG_L1 ... Training model for up to 745.13s of the 745.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	0.8812	 = Validation score   (roc_auc)
# 	13.52s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTrees_r178_BAG_L1 ... Training model for up to 729.17s of the 729.16s of remaining time.
# 	0.8728	 = Validation score   (roc_auc)
# 	1.23s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L1 ... Training model for up to 727.39s of the 727.39s of remaining time.
# 	0.8645	 = Validation score   (roc_auc)
# 	1.55s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: XGBoost_r31_BAG_L1 ... Training model for up to 725.28s of the 725.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8789	 = Validation score   (roc_auc)
# 	10.53s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: NeuralNetTorch_r185_BAG_L1 ... Training model for up to 712.36s of the 712.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8711	 = Validation score   (roc_auc)
# 	37.27s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r160_BAG_L1 ... Training model for up to 672.81s of the 672.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8746	 = Validation score   (roc_auc)
# 	41.56s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: CatBoost_r60_BAG_L1 ... Training model for up to 628.79s of the 628.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.50%)
# 	0.8818	 = Validation score   (roc_auc)
# 	10.1s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_r15_BAG_L1 ... Training model for up to 615.64s of the 615.63s of remaining time.
# 	0.8605	 = Validation score   (roc_auc)
# 	5.78s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: LightGBM_r135_BAG_L1 ... Training model for up to 609.35s of the 609.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.72%)
# 	0.8734	 = Validation score   (roc_auc)
# 	5.1s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: XGBoost_r22_BAG_L1 ... Training model for up to 601.85s of the 601.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8788	 = Validation score   (roc_auc)
# 	3.47s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r69_BAG_L1 ... Training model for up to 595.84s of the 595.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8758	 = Validation score   (roc_auc)
# 	32.55s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: CatBoost_r6_BAG_L1 ... Training model for up to 560.75s of the 560.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	0.88	 = Validation score   (roc_auc)
# 	6.75s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r138_BAG_L1 ... Training model for up to 551.09s of the 551.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.8751	 = Validation score   (roc_auc)
# 	129.08s	 = Training   runtime
# 	0.74s	 = Validation runtime
# Fitting model: LightGBM_r121_BAG_L1 ... Training model for up to 419.52s of the 419.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.75%)
# 	0.8747	 = Validation score   (roc_auc)
# 	6.85s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r172_BAG_L1 ... Training model for up to 410.14s of the 410.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.8736	 = Validation score   (roc_auc)
# 	18.75s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost_r180_BAG_L1 ... Training model for up to 388.99s of the 388.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.65%)
# 	0.8792	 = Validation score   (roc_auc)
# 	21.75s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r76_BAG_L1 ... Training model for up to 364.62s of the 364.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8737	 = Validation score   (roc_auc)
# 	19.63s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: ExtraTrees_r197_BAG_L1 ... Training model for up to 342.6s of the 342.6s of remaining time.
# 	0.8651	 = Validation score   (roc_auc)
# 	1.51s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: NeuralNetTorch_r121_BAG_L1 ... Training model for up to 340.55s of the 340.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8713	 = Validation score   (roc_auc)
# 	271.3s	 = Training   runtime
# 	1.56s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r127_BAG_L1 ... Training model for up to 66.54s of the 66.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.8732	 = Validation score   (roc_auc)
# 	12.58s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: RandomForest_r16_BAG_L1 ... Training model for up to 51.68s of the 51.68s of remaining time.
# 	0.8523	 = Validation score   (roc_auc)
# 	8.7s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r194_BAG_L1 ... Training model for up to 42.46s of the 42.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8739	 = Validation score   (roc_auc)
# 	27.99s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: CatBoost_r12_BAG_L1 ... Training model for up to 12.13s of the 12.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.76%)
# 	0.88	 = Validation score   (roc_auc)
# 	11.08s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the -2.25s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.214, 'CatBoost_r137_BAG_L1': 0.143, 'LightGBM_r96_BAG_L1': 0.112, 'NeuralNetTorch_r31_BAG_L1': 0.112, 'XGBoost_r89_BAG_L1': 0.102, 'NeuralNetTorch_r76_BAG_L1': 0.102, 'NeuralNetTorch_r86_BAG_L1': 0.071, 'CatBoost_r5_BAG_L1': 0.071, 'NeuralNetFastAI_r191_BAG_L1': 0.061, 'XGBoost_r22_BAG_L1': 0.01}
# 	0.8857	 = Validation score   (roc_auc)
# 	4.85s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 2691.12s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240319_235904")

# %%
bumps_predictor.evaluate(xtrain_bumps)
# Out:
# {'roc_auc': 0.9310208306075798,
#  'accuracy': 0.9292972575905974,
#  'balanced_accuracy': 0.5416709480942064,
#  'mcc': 0.2601406848662326,
#  'f1': 0.15384615384615385,
#  'precision': 0.8823529411764706,
#  'recall': 0.08426966292134831}

# %%
bumps_predictor.evaluate(xtest_bumps)
# Out:
# {'roc_auc': 0.8849383811832179,
#  'accuracy': 0.9240374609781478,
#  'balanced_accuracy': 0.5147825419042091,
#  'mcc': 0.1171556973782576,
#  'f1': 0.060085836909871244,
#  'precision': 0.5384615384615384,
#  'recall': 0.031818181818181815}

# %%
xtr_other_faults, xte_other_faults, ytr_other_faults, yte_other_faults = train_test_split(X,other_faults,test_size=0.05, stratify=other_faults, random_state=0)

# %%
xtrain_other_faults = pd.concat([xtr_other_faults,ytr_other_faults], axis=1)
xtest_other_faults = pd.concat([xte_other_faults,yte_other_faults], axis=1)

# %%
other_faults_predictor = TabularPredictor(label='Other_Faults', eval_metric='roc_auc')
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240319_235904"

# %%
other_faults_predictor.fit(xtrain_other_faults, time_limit=3600, presets='best_quality')
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 3600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240319_235904/ds_sub_fit/sub_fit_ho.
# Beginning AutoGluon training ... Time limit = 900s
# AutoGluon will save models to "AutogluonModels\ag-20240319_235904/ds_sub_fit/sub_fit_ho"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.9.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       8.07 GB / 15.63 GB (51.6%)
# Disk Space Avail:   161.78 GB / 241.59 GB (67.0%)
# ===================================================
# Train Data Rows:    17868
# Train Data Columns: 27
# Label Column:       Pastry
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8261.02 MB
# 	Train Data (Original)  Memory Usage: 3.68 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 14 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  2 | ['TypeOfSteel_A300', 'TypeOfSteel_A400']
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.44 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 599.8s of the 899.9s of remaining time.
# 	0.5383	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 595.08s of the 895.19s of remaining time.
# 	0.5393	 = Validation score   (roc_auc)
# 	0.03s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 594.71s of the 894.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8792	 = Validation score   (roc_auc)
# 	1.39s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 581.59s of the 881.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.8762	 = Validation score   (roc_auc)
# 	2.55s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 576.81s of the 876.92s of remaining time.
# 	0.8614	 = Validation score   (roc_auc)
# 	1.42s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 574.86s of the 874.97s of remaining time.
# 	0.8672	 = Validation score   (roc_auc)
# 	1.42s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 572.93s of the 873.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.8804	 = Validation score   (roc_auc)
# 	9.49s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 561.47s of the 861.58s of remaining time.
# 	0.8653	 = Validation score   (roc_auc)
# 	0.79s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 560.1s of the 860.21s of remaining time.
# 	0.8691	 = Validation score   (roc_auc)
# 	0.78s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 558.73s of the 858.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.8698	 = Validation score   (roc_auc)
# 	22.51s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 534.18s of the 834.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.8746	 = Validation score   (roc_auc)
# 	3.43s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 528.0s of the 828.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8732	 = Validation score   (roc_auc)
# 	20.56s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 505.15s of the 805.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# 	0.8714	 = Validation score   (roc_auc)
# 	4.63s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 498.09s of the 798.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	0.8778	 = Validation score   (roc_auc)
# 	8.68s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 487.03s of the 787.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.8721	 = Validation score   (roc_auc)
# 	41.81s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 442.89s of the 743.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.41%)
# 	0.8764	 = Validation score   (roc_auc)
# 	4.52s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 435.98s of the 736.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.8726	 = Validation score   (roc_auc)
# 	74.2s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 359.47s of the 659.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.82%)
# 	0.8801	 = Validation score   (roc_auc)
# 	41.47s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 315.81s of the 615.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.8805	 = Validation score   (roc_auc)
# 	5.61s	 = Training   runtime
# 	1.28s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 307.66s of the 607.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.8745	 = Validation score   (roc_auc)
# 	71.33s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 233.72s of the 533.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.40%)
# 	0.8743	 = Validation score   (roc_auc)
# 	10.52s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 220.56s of the 520.67s of remaining time.
# 	0.8652	 = Validation score   (roc_auc)
# 	1.21s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 218.79s of the 518.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	0.8787	 = Validation score   (roc_auc)
# 	9.12s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 207.22s of the 507.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	0.8739	 = Validation score   (roc_auc)
# 	13.89s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 190.66s of the 490.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.99%)
# 	0.8806	 = Validation score   (roc_auc)
# 	52.28s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 135.32s of the 435.43s of remaining time.
# 	0.8525	 = Validation score   (roc_auc)
# 	5.66s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 129.11s of the 429.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# 	0.8755	 = Validation score   (roc_auc)
# 	4.6s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 121.81s of the 421.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.50%)
# 	0.8731	 = Validation score   (roc_auc)
# 	59.19s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 60.03s of the 360.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8771	 = Validation score   (roc_auc)
# 	3.84s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 53.16s of the 353.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# 	0.8651	 = Validation score   (roc_auc)
# 	45.92s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 4.54s of the 304.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# 	0.8749	 = Validation score   (roc_auc)
# 	3.72s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 297.75s of remaining time.
# 	Ensemble Weights: {'CatBoost_r9_BAG_L1': 0.18, 'CatBoost_BAG_L1': 0.14, 'LightGBMXT_BAG_L1': 0.1, 'NeuralNetTorch_r79_BAG_L1': 0.08, 'LightGBM_r96_BAG_L1': 0.08, 'NeuralNetTorch_BAG_L1': 0.07, 'CatBoost_r137_BAG_L1': 0.07, 'LightGBM_BAG_L1': 0.06, 'NeuralNetTorch_r22_BAG_L1': 0.06, 'ExtraTreesEntr_BAG_L1': 0.05, 'ExtraTrees_r42_BAG_L1': 0.05, 'NeuralNetFastAI_r145_BAG_L1': 0.04, 'NeuralNetFastAI_r102_BAG_L1': 0.01, 'CatBoost_r13_BAG_L1': 0.01}
# 	0.8838	 = Validation score   (roc_auc)
# 	4.35s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 293.37s of the 293.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.8808	 = Validation score   (roc_auc)
# 	4.21s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 286.87s of the 286.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8794	 = Validation score   (roc_auc)
# 	4.75s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 279.32s of the 279.23s of remaining time.
# 	0.8702	 = Validation score   (roc_auc)
# 	3.84s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 274.82s of the 274.73s of remaining time.
# 	0.8726	 = Validation score   (roc_auc)
# 	3.8s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 270.36s of the 270.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.71%)
# 	0.8819	 = Validation score   (roc_auc)
# 	17.05s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 250.76s of the 250.67s of remaining time.
# 	0.8723	 = Validation score   (roc_auc)
# 	0.94s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 249.07s of the 248.99s of remaining time.
# 	0.8769	 = Validation score   (roc_auc)
# 	0.95s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 247.44s of the 247.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.77%)
# 	0.8803	 = Validation score   (roc_auc)
# 	28.17s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 216.69s of the 216.6s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.03%)
# 	0.8756	 = Validation score   (roc_auc)
# 	6.27s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 207.5s of the 207.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	0.8807	 = Validation score   (roc_auc)
# 	23.42s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 181.19s of the 181.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.00%)
# 	0.8757	 = Validation score   (roc_auc)
# 	9.05s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 169.52s of the 169.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.76%)
# 	0.8812	 = Validation score   (roc_auc)
# 	13.25s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 153.52s of the 153.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.8704	 = Validation score   (roc_auc)
# 	36.53s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 114.23s of the 114.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8801	 = Validation score   (roc_auc)
# 	7.04s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 104.43s of the 104.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.81%)
# 	0.88	 = Validation score   (roc_auc)
# 	84.06s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 17.58s of the 17.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.54%)
# 	0.8812	 = Validation score   (roc_auc)
# 	15.64s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -1.51s of remaining time.
# 	Ensemble Weights: {'NeuralNetTorch_BAG_L2': 0.208, 'CatBoost_BAG_L1': 0.17, 'LightGBM_BAG_L2': 0.113, 'LightGBMXT_BAG_L1': 0.094, 'ExtraTreesEntr_BAG_L2': 0.094, 'NeuralNetTorch_r22_BAG_L1': 0.075, 'NeuralNetTorch_BAG_L1': 0.038, 'CatBoost_BAG_L2': 0.038, 'NeuralNetFastAI_BAG_L2': 0.038, 'LightGBM_r131_BAG_L2': 0.038, 'NeuralNetFastAI_r191_BAG_L2': 0.038, 'LightGBM_r96_BAG_L1': 0.019, 'NeuralNetFastAI_r145_BAG_L1': 0.019, 'LightGBMXT_BAG_L2': 0.019}
# 	0.8841	 = Validation score   (roc_auc)
# 	4.29s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 905.83s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240319_235904/ds_sub_fit/sub_fit_ho")
# Leaderboard on holdout data from dynamic stacking:
#                           model  holdout_score  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         ExtraTreesGini_BAG_L2       0.886075   0.872285     roc_auc        6.168901       9.615628  527.536743                 0.139452                0.597560           0.939641            2       True         38
# 1           CatBoost_r13_BAG_L1       0.882981   0.880568     roc_auc        0.079700       0.021796   52.279622                 0.079700                0.021796          52.279622            1       True         25
# 2               CatBoost_BAG_L1       0.882216   0.880400     roc_auc        0.070155       0.023550    9.486506                 0.070155                0.023550           9.486506            1       True          7
# 3         ExtraTreesEntr_BAG_L2       0.881724   0.876928     roc_auc        6.166894       9.559421  527.550747                 0.137444                0.541353           0.953644            2       True         39
# 4           WeightedEnsemble_L2       0.881300   0.883821     roc_auc        2.793190       4.007383  335.042710                 0.015615                0.000000           4.353752            2       True         32
# 5     NeuralNetTorch_r79_BAG_L2       0.881261   0.870350     roc_auc        6.454637       9.523753  563.123564                 0.425187                0.505685          36.526461            2       True         45
# 6          CatBoost_r177_BAG_L1       0.880748   0.877778     roc_auc        0.076017       0.006998    8.683343                 0.076017                0.006998           8.683343            1       True         14
# 7       RandomForestEntr_BAG_L2       0.880385   0.872607     roc_auc        6.126806       9.559780  530.397282                 0.097357                0.541711           3.800179            2       True         36
# 8           WeightedEnsemble_L3       0.880335   0.884130     roc_auc        7.768425      11.292774  700.545946                 0.007060                0.004205           4.294727            3       True         49
# 9   NeuralNetFastAI_r191_BAG_L2       0.880005   0.880032     roc_auc        6.473518       9.491831  610.656833                 0.444069                0.473763          84.059730            2       True         47
# 10       NeuralNetFastAI_BAG_L2       0.879863   0.880308     roc_auc        6.349186       9.307555  554.767097                 0.319737                0.289486          28.169994            2       True         40
# 11         CatBoost_r137_BAG_L1       0.879220   0.878721     roc_auc        0.069793       0.021118    9.117200                 0.069793                0.021118           9.117200            1       True         23
# 12        ExtraTreesGini_BAG_L1       0.878836   0.865331     roc_auc        0.149536       0.437159    0.791780                 0.149536                0.437159           0.791780            1       True          8
# 13          LightGBM_r96_BAG_L1       0.878681   0.880512     roc_auc        0.312201       1.279613    5.612621                 0.312201                1.279613           5.612621            1       True         19
# 14            LightGBMXT_BAG_L1       0.877953   0.879194     roc_auc        0.117598       0.138067    1.388801                 0.117598                0.138067           1.388801            1       True          3
# 15  NeuralNetFastAI_r145_BAG_L1       0.877902   0.873087     roc_auc        0.535821       0.506605   59.192522                 0.535821                0.506605          59.192522            1       True         28
# 16              CatBoost_BAG_L2       0.877831   0.881917     roc_auc        6.099073       9.052424  543.650275                 0.069623                0.034356          17.053172            2       True         37
# 17         LightGBM_r131_BAG_L2       0.877729   0.880114     roc_auc        6.182606       9.350170  533.637658                 0.153157                0.332101           7.040556            2       True         46
# 18               XGBoost_BAG_L2       0.877706   0.875649     roc_auc        6.223950       9.131317  532.862148                 0.194501                0.113249           6.265045            2       True         41
# 19           CatBoost_r9_BAG_L2       0.877576   0.881162     roc_auc        6.123221       9.056681  542.241074                 0.093772                0.038613          15.643971            2       True         48
# 20  NeuralNetFastAI_r102_BAG_L1       0.877573   0.873891     roc_auc        0.208187       0.162838   13.893986                 0.208187                0.162838          13.893986            1       True         24
# 21         CatBoost_r177_BAG_L2       0.877080   0.881196     roc_auc        6.115743       9.035885  539.846204                 0.086293                0.017817          13.249101            2       True         44
# 22           CatBoost_r9_BAG_L1       0.876932   0.880114     roc_auc        0.094117       0.045573   41.472841                 0.094117                0.045573          41.472841            1       True         18
# 23            LightGBMXT_BAG_L2       0.876739   0.880811     roc_auc        6.161368       9.156579  530.811756                 0.131919                0.138510           4.214653            2       True         33
# 24              LightGBM_BAG_L2       0.876569   0.879394     roc_auc        6.131878       9.091086  531.343797                 0.102429                0.073017           4.746694            2       True         34
# 25  NeuralNetFastAI_r191_BAG_L1       0.876521   0.872592     roc_auc        0.413093       0.408375   74.197654                 0.413093                0.408375          74.197654            1       True         17
# 26        ExtraTreesEntr_BAG_L1       0.876460   0.869131     roc_auc        0.146610       0.443194    0.777706                 0.146610                0.443194           0.777706            1       True          9
# 27      RandomForestGini_BAG_L2       0.876330   0.870204     roc_auc        6.175297       9.538392  530.432986                 0.145848                0.520324           3.835883            2       True         35
# 28         LightGBMLarge_BAG_L2       0.876147   0.875682     roc_auc        6.129883       9.138606  535.643606                 0.100434                0.120538           9.046503            2       True         43
# 29    NeuralNetTorch_r30_BAG_L1       0.876085   0.865067     roc_auc        0.409509       0.507041   45.924040                 0.409509                0.507041          45.924040            1       True         30
# 30         LightGBM_r130_BAG_L1       0.875895   0.874853     roc_auc        0.097383       0.156948    3.721794                 0.097383                0.156948           3.721794            1       True         31
# 31         LightGBM_r188_BAG_L1       0.875447   0.875508     roc_auc        0.162367       0.281671    4.603788                 0.162367                0.281671           4.603788            1       True         27
# 32    NeuralNetTorch_r79_BAG_L1       0.875263   0.872129     roc_auc        0.277132       0.245018   41.808169                 0.277132                0.245018          41.808169            1       True         15
# 33    NeuralNetTorch_r22_BAG_L1       0.875243   0.874470     roc_auc        0.360991       0.460422   71.334427                 0.360991                0.460422          71.334427            1       True         20
# 34       NeuralNetFastAI_BAG_L1       0.874888   0.869829     roc_auc        0.448457       0.239393   22.505132                 0.448457                0.239393          22.505132            1       True         10
# 35           XGBoost_r89_BAG_L1       0.873412   0.877127     roc_auc        0.179844       0.116353    3.835121                 0.179844                0.116353           3.835121            1       True         29
# 36              LightGBM_BAG_L1       0.872845   0.876230     roc_auc        0.090186       0.092776    2.551873                 0.090186                0.092776           2.551873            1       True          4
# 37        NeuralNetTorch_BAG_L2       0.872711   0.880659     roc_auc        6.402986       9.405982  550.012776                 0.373537                0.387913          23.415673            2       True         42
# 38               XGBoost_BAG_L1       0.872442   0.874569     roc_auc        0.182594       0.069535    3.430156                 0.182594                0.069535           3.430156            1       True         11
# 39         LightGBMLarge_BAG_L1       0.872110   0.871425     roc_auc        0.110489       0.151481    4.626272                 0.110489                0.151481           4.626272            1       True         13
# 40           XGBoost_r33_BAG_L1       0.871943   0.874338     roc_auc        0.369906       0.391560   10.519028                 0.369906                0.391560          10.519028            1       True         21
# 41        ExtraTrees_r42_BAG_L1       0.871861   0.865187     roc_auc        0.164536       0.419793    1.213027                 0.164536                0.419793           1.213027            1       True         22
# 42         LightGBM_r131_BAG_L1       0.871770   0.876379     roc_auc        0.167480       0.412121    4.520247                 0.167480                0.412121           4.520247            1       True         16
# 43        NeuralNetTorch_BAG_L1       0.870027   0.873242     roc_auc        0.250550       0.147019   20.559657                 0.250550                0.147019          20.559657            1       True         12
# 44      RandomForestEntr_BAG_L1       0.868240   0.867192     roc_auc        0.107049       0.382377    1.421225                 0.107049                0.382377           1.421225            1       True          6
# 45      RandomForestGini_BAG_L1       0.864563   0.861442     roc_auc        0.145463       0.405813    1.421673                 0.145463                0.405813           1.421673            1       True          5
# 46     RandomForest_r195_BAG_L1       0.854246   0.852451     roc_auc        0.104702       0.416820    5.663337                 0.104702                0.416820           5.663337            1       True         26
# 47        KNeighborsUnif_BAG_L1       0.583097   0.538270     roc_auc        0.064108       0.319164    0.015737                 0.064108                0.319164           0.015737            1       True          1
# 48        KNeighborsDist_BAG_L1       0.578165   0.539345     roc_auc        0.063878       0.307874    0.027819                 0.063878                0.307874           0.027819            1       True          2
# Stacked overfitting occurred: True.
# Spend 916 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 2684 seconds.
# Starting full fit now with num_stack_levels 0.
# Beginning AutoGluon training ... Time limit = 2684s
# AutoGluon will save models to "AutogluonModels\ag-20240319_235904"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.9.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       8.06 GB / 15.63 GB (51.6%)
# Disk Space Avail:   161.78 GB / 241.59 GB (67.0%)
# ===================================================
# Train Data Rows:    20102
# Train Data Columns: 27
# Label Column:       Pastry
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    8254.76 MB
# 	Train Data (Original)  Memory Usage: 4.14 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])   : 14 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 13 | ['Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', ...]
# 		('int', [])       : 12 | ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', ...]
# 		('int', ['bool']) :  2 | ['TypeOfSteel_A300', 'TypeOfSteel_A400']
# 	0.1s = Fit runtime
# 	27 features in original data used to generate 27 features in processed data.
# 	Train Data (Processed) Memory Usage: 3.87 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2683.9s of the 2683.89s of remaining time.
# 	0.5379	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2683.26s of the 2683.25s of remaining time.
# 	0.5396	 = Validation score   (roc_auc)
# 	0.02s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2682.65s of the 2682.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# 	0.8794	 = Validation score   (roc_auc)
# 	3.06s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2677.17s of the 2677.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# 	0.8768	 = Validation score   (roc_auc)
# 	2.88s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2671.79s of the 2671.78s of remaining time.
# 	0.8614	 = Validation score   (roc_auc)
# 	1.99s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2669.24s of the 2669.23s of remaining time.
# 	0.8684	 = Validation score   (roc_auc)
# 	1.89s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2666.81s of the 2666.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	0.8821	 = Validation score   (roc_auc)
# 	14.16s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2650.35s of the 2650.35s of remaining time.
# 	0.8677	 = Validation score   (roc_auc)
# 	0.9s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2648.85s of the 2648.85s of remaining time.
# 	0.8702	 = Validation score   (roc_auc)
# 	0.86s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2647.37s of the 2647.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.873	 = Validation score   (roc_auc)
# 	25.68s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2619.47s of the 2619.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8752	 = Validation score   (roc_auc)
# 	3.48s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2613.46s of the 2613.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	0.8721	 = Validation score   (roc_auc)
# 	24.09s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2586.86s of the 2586.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# 	0.8725	 = Validation score   (roc_auc)
# 	5.2s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 2579.11s of the 2579.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# 	0.8801	 = Validation score   (roc_auc)
# 	11.81s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 2564.59s of the 2564.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8702	 = Validation score   (roc_auc)
# 	36.41s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 2525.72s of the 2525.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	0.8781	 = Validation score   (roc_auc)
# 	4.59s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 2518.62s of the 2518.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	0.8751	 = Validation score   (roc_auc)
# 	82.42s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 2433.68s of the 2433.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.88%)
# 	0.879	 = Validation score   (roc_auc)
# 	36.26s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 2394.85s of the 2394.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.8817	 = Validation score   (roc_auc)
# 	6.3s	 = Training   runtime
# 	1.73s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 2385.78s of the 2385.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8734	 = Validation score   (roc_auc)
# 	71.35s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 2311.95s of the 2311.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.45%)
# 	0.8748	 = Validation score   (roc_auc)
# 	9.78s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 2299.68s of the 2299.67s of remaining time.
# 	0.8641	 = Validation score   (roc_auc)
# 	1.31s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 2297.8s of the 2297.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8818	 = Validation score   (roc_auc)
# 	10.99s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 2284.28s of the 2284.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8736	 = Validation score   (roc_auc)
# 	14.17s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 2267.81s of the 2267.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.08%)
# 	0.8812	 = Validation score   (roc_auc)
# 	53.68s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 2211.01s of the 2211.0s of remaining time.
# 	0.8537	 = Validation score   (roc_auc)
# 	6.54s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 2203.87s of the 2203.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.877	 = Validation score   (roc_auc)
# 	5.31s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 2195.76s of the 2195.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# 	0.8754	 = Validation score   (roc_auc)
# 	59.15s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 2133.8s of the 2133.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8795	 = Validation score   (roc_auc)
# 	3.66s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 2126.87s of the 2126.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.8705	 = Validation score   (roc_auc)
# 	75.31s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 2048.68s of the 2048.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# ...
# 	23.11s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: XGBoost_r98_BAG_L1 ... Training model for up to 1576.51s of the 1576.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.91%)
# 	0.8785	 = Validation score   (roc_auc)
# 	13.77s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: LightGBM_r15_BAG_L1 ... Training model for up to 1560.41s of the 1560.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.8791	 = Validation score   (roc_auc)
# 	3.66s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 1554.26s of the 1554.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.8592	 = Validation score   (roc_auc)
# 	285.37s	 = Training   runtime
# 	1.34s	 = Validation runtime
# Fitting model: CatBoost_r86_BAG_L1 ... Training model for up to 1266.26s of the 1266.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.84%)
# 	0.8795	 = Validation score   (roc_auc)
# 	26.18s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37_BAG_L1 ... Training model for up to 1237.83s of the 1237.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8744	 = Validation score   (roc_auc)
# 	35.64s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197_BAG_L1 ... Training model for up to 1199.9s of the 1199.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.8724	 = Validation score   (roc_auc)
# 	18.61s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: CatBoost_r49_BAG_L1 ... Training model for up to 1178.76s of the 1178.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# 	0.881	 = Validation score   (roc_auc)
# 	7.97s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTrees_r49_BAG_L1 ... Training model for up to 1168.53s of the 1168.53s of remaining time.
# 	0.8677	 = Validation score   (roc_auc)
# 	1.0s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: LightGBM_r143_BAG_L1 ... Training model for up to 1166.89s of the 1166.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	0.871	 = Validation score   (roc_auc)
# 	7.14s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: RandomForest_r127_BAG_L1 ... Training model for up to 1157.23s of the 1157.22s of remaining time.
# 	0.8631	 = Validation score   (roc_auc)
# 	7.49s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134_BAG_L1 ... Training model for up to 1149.23s of the 1149.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8712	 = Validation score   (roc_auc)
# 	64.1s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: RandomForest_r34_BAG_L1 ... Training model for up to 1082.68s of the 1082.67s of remaining time.
# 	0.8705	 = Validation score   (roc_auc)
# 	4.39s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: LightGBM_r94_BAG_L1 ... Training model for up to 1077.81s of the 1077.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	0.8806	 = Validation score   (roc_auc)
# 	3.62s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143_BAG_L1 ... Training model for up to 1071.52s of the 1071.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8747	 = Validation score   (roc_auc)
# 	92.13s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: CatBoost_r128_BAG_L1 ... Training model for up to 977.01s of the 977.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.83%)
# 	0.8783	 = Validation score   (roc_auc)
# 	33.92s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111_BAG_L1 ... Training model for up to 940.81s of the 940.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.875	 = Validation score   (roc_auc)
# 	17.28s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31_BAG_L1 ... Training model for up to 921.16s of the 921.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# 	0.875	 = Validation score   (roc_auc)
# 	36.04s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: ExtraTrees_r4_BAG_L1 ... Training model for up to 882.35s of the 882.34s of remaining time.
# 	0.8738	 = Validation score   (roc_auc)
# 	1.08s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65_BAG_L1 ... Training model for up to 880.8s of the 880.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8689	 = Validation score   (roc_auc)
# 	21.65s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r88_BAG_L1 ... Training model for up to 856.81s of the 856.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.71%)
# 	0.8743	 = Validation score   (roc_auc)
# 	23.51s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_r30_BAG_L1 ... Training model for up to 830.64s of the 830.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.8782	 = Validation score   (roc_auc)
# 	7.47s	 = Training   runtime
# 	1.38s	 = Validation runtime
# Fitting model: XGBoost_r49_BAG_L1 ... Training model for up to 820.29s of the 820.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.68%)
# 	0.8764	 = Validation score   (roc_auc)
# 	5.6s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: CatBoost_r5_BAG_L1 ... Training model for up to 812.15s of the 812.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# 	0.8815	 = Validation score   (roc_auc)
# 	13.31s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r87_BAG_L1 ... Training model for up to 796.22s of the 796.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8708	 = Validation score   (roc_auc)
# 	35.68s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_r71_BAG_L1 ... Training model for up to 758.19s of the 758.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	0.8732	 = Validation score   (roc_auc)
# 	10.7s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r143_BAG_L1 ... Training model for up to 745.13s of the 745.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# 	0.8812	 = Validation score   (roc_auc)
# 	13.52s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTrees_r178_BAG_L1 ... Training model for up to 729.17s of the 729.16s of remaining time.
# 	0.8728	 = Validation score   (roc_auc)
# 	1.23s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L1 ... Training model for up to 727.39s of the 727.39s of remaining time.
# 	0.8645	 = Validation score   (roc_auc)
# 	1.55s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: XGBoost_r31_BAG_L1 ... Training model for up to 725.28s of the 725.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	0.8789	 = Validation score   (roc_auc)
# 	10.53s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: NeuralNetTorch_r185_BAG_L1 ... Training model for up to 712.36s of the 712.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8711	 = Validation score   (roc_auc)
# 	37.27s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r160_BAG_L1 ... Training model for up to 672.81s of the 672.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8746	 = Validation score   (roc_auc)
# 	41.56s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: CatBoost_r60_BAG_L1 ... Training model for up to 628.79s of the 628.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.50%)
# 	0.8818	 = Validation score   (roc_auc)
# 	10.1s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_r15_BAG_L1 ... Training model for up to 615.64s of the 615.63s of remaining time.
# 	0.8605	 = Validation score   (roc_auc)
# 	5.78s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: LightGBM_r135_BAG_L1 ... Training model for up to 609.35s of the 609.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.72%)
# 	0.8734	 = Validation score   (roc_auc)
# 	5.1s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: XGBoost_r22_BAG_L1 ... Training model for up to 601.85s of the 601.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8788	 = Validation score   (roc_auc)
# 	3.47s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r69_BAG_L1 ... Training model for up to 595.84s of the 595.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	0.8758	 = Validation score   (roc_auc)
# 	32.55s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: CatBoost_r6_BAG_L1 ... Training model for up to 560.75s of the 560.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	0.88	 = Validation score   (roc_auc)
# 	6.75s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r138_BAG_L1 ... Training model for up to 551.09s of the 551.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.8751	 = Validation score   (roc_auc)
# 	129.08s	 = Training   runtime
# 	0.74s	 = Validation runtime
# Fitting model: LightGBM_r121_BAG_L1 ... Training model for up to 419.52s of the 419.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.75%)
# 	0.8747	 = Validation score   (roc_auc)
# 	6.85s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r172_BAG_L1 ... Training model for up to 410.14s of the 410.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# 	0.8736	 = Validation score   (roc_auc)
# 	18.75s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost_r180_BAG_L1 ... Training model for up to 388.99s of the 388.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.65%)
# 	0.8792	 = Validation score   (roc_auc)
# 	21.75s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r76_BAG_L1 ... Training model for up to 364.62s of the 364.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8737	 = Validation score   (roc_auc)
# 	19.63s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: ExtraTrees_r197_BAG_L1 ... Training model for up to 342.6s of the 342.6s of remaining time.
# 	0.8651	 = Validation score   (roc_auc)
# 	1.51s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: NeuralNetTorch_r121_BAG_L1 ... Training model for up to 340.55s of the 340.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	0.8713	 = Validation score   (roc_auc)
# 	271.3s	 = Training   runtime
# 	1.56s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r127_BAG_L1 ... Training model for up to 66.54s of the 66.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.56%)
# 	0.8732	 = Validation score   (roc_auc)
# 	12.58s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: RandomForest_r16_BAG_L1 ... Training model for up to 51.68s of the 51.68s of remaining time.
# 	0.8523	 = Validation score   (roc_auc)
# 	8.7s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r194_BAG_L1 ... Training model for up to 42.46s of the 42.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.55%)
# 	0.8739	 = Validation score   (roc_auc)
# 	27.99s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: CatBoost_r12_BAG_L1 ... Training model for up to 12.13s of the 12.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.76%)
# 	0.88	 = Validation score   (roc_auc)
# 	11.08s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the -2.25s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.214, 'CatBoost_r137_BAG_L1': 0.143, 'LightGBM_r96_BAG_L1': 0.112, 'NeuralNetTorch_r31_BAG_L1': 0.112, 'XGBoost_r89_BAG_L1': 0.102, 'NeuralNetTorch_r76_BAG_L1': 0.102, 'NeuralNetTorch_r86_BAG_L1': 0.071, 'CatBoost_r5_BAG_L1': 0.071, 'NeuralNetFastAI_r191_BAG_L1': 0.061, 'XGBoost_r22_BAG_L1': 0.01}
# 	0.8857	 = Validation score   (roc_auc)
# 	4.85s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 2691.12s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240319_235904")

# %%
other_faults_predictor.evaluate(xtrain_other_faults)
# Out:
# {'roc_auc': 0.9310208306075798,
#  'accuracy': 0.9292972575905974,
#  'balanced_accuracy': 0.5416709480942064,
#  'mcc': 0.2601406848662326,
#  'f1': 0.15384615384615385,
#  'precision': 0.8823529411764706,
#  'recall': 0.08426966292134831}

# %%
other_faults_predictor.evaluate(xtest_other_faults)
# Out:
# {'roc_auc': 0.8849383811832179,
#  'accuracy': 0.9240374609781478,
#  'balanced_accuracy': 0.5147825419042091,
#  'mcc': 0.1171556973782576,
#  'f1': 0.060085836909871244,
#  'precision': 0.5384615384615384,
#  'recall': 0.031818181818181815}
